# %%
#importing packages.
import pandas as pd
from collections import Counter

# %%
#DATA COLLECTION - fetching raw database in csv format from url.
url = 'https://raw.githubusercontent.com/coinmetrics-io/data/master/csv/btc.csv'
raw_data = pd.read_csv(url)
raw_data.tail()
# Out:
#             time  AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# 4325  2020-11-06  1080743.0   153.0  194685185.0     1.272452e+06    2.299192
# 4326  2020-11-07  1055012.0   146.0  198604086.0     1.360302e+06    2.187115
# 4327  2020-11-08   920529.0   138.0  189145770.0     1.370622e+06    2.269764
# 4328  2020-11-09  1188873.0   185.0  252934375.0     1.367213e+06    2.237517
# 4329  2020-11-10  1026623.0   147.0  180843729.0     1.230229e+06    2.232287
#
#       CapMrktCurUSD    CapRealUSD      DiffMean  FeeMeanNtv  ...  \
# 4325   2.895100e+11  1.259182e+11  1.678778e+13    0.000684  ...
# 4326   2.755732e+11  1.259985e+11  1.678778e+13    0.000500  ...
# 4327   2.873323e+11  1.265912e+11  1.678778e+13    0.000384  ...
# 4328   2.840099e+11  1.269308e+11  1.678778e+13    0.000440  ...
# 4329   2.840139e+11  1.272300e+11  1.678778e+13    0.000507  ...
#
#       TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  \
# 4325    5.377085e+09         0.798253     12467.889939        0.008849
# 4326    3.113639e+09         0.600304      8924.329906        0.006843
# 4327    2.807229e+09         0.637306      9878.241843        0.006680
# 4328    4.587933e+09         0.713117     10924.823338        0.008200
# 4329    4.678510e+09         0.739668     11331.173774        0.008271
#
#       TxTfrValMedUSD    TxTfrValNtv   TxTfrValUSD  VtyDayRet180d  \
# 4325      138.219785  706950.322346  1.104184e+10       0.025758
# 4326      101.735828  444455.314929  6.607431e+09       0.026023
# 4327      103.540005  420998.539315  6.525478e+09       0.026128
# 4328      125.622524  603186.409034  9.240707e+09       0.025851
# 4329      126.700214  620125.585166  9.499875e+09       0.025607
#
#       VtyDayRet30d  VtyDayRet60d
# 4325      0.024822      0.022120
# 4326      0.027211      0.022916
# 4327      0.027797      0.023359
# 4328      0.028047      0.023476
# 4329      0.028102      0.023490
#
# [5 rows x 43 columns]

# %%
#Info from raw_data
#43 columns and 4329 rows
#All columns are floats, except the first column 'time' (object type), which is the date.
#Column PriceUSD, the price of bitcoin in USD, has 3768 entries.
#For modeling purposes we may have to drop the rows where PriceUSD is null.
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4330 entries, 0 to 4329
# Data columns (total 43 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   time                4330 non-null   object
#  1   AdrActCnt           4330 non-null   float64
#  2   BlkCnt              4330 non-null   float64
#  3   BlkSizeByte         4330 non-null   float64
#  4   BlkSizeMeanByte     4324 non-null   float64
#  5   CapMVRVCur          3769 non-null   float64
#  6   CapMrktCurUSD       3769 non-null   float64
#  7   CapRealUSD          4330 non-null   float64
#  8   DiffMean            4324 non-null   float64
#  9   FeeMeanNtv          4072 non-null   float64
#  10  FeeMeanUSD          3769 non-null   float64
#  11  FeeMedNtv           4072 non-null   float64
#  12  FeeMedUSD           3769 non-null   float64
#  13  FeeTotNtv           4330 non-null   float64
#  14  FeeTotUSD           3769 non-null   float64
#  15  HashRate            4324 non-null   float64
#  16  IssContNtv          4324 non-null   float64
#  17  IssContPctAnn       4324 non-null   float64
#  18  IssContUSD          3769 non-null   float64
#  19  IssTotNtv           4324 non-null   float64
#  20  IssTotUSD           3769 non-null   float64
#  21  NVTAdj              4070 non-null   float64
#  22  NVTAdj90            3680 non-null   float64
#  23  PriceBTC            4330 non-null   float64
#  24  PriceUSD            3769 non-null   float64
#  25  ROI1yr              3404 non-null   float64
#  26  ROI30d              3739 non-null   float64
#  27  SplyCur             4330 non-null   float64
#  28  SplyExpFut10yrCMBI  4324 non-null   float64
#  29  SplyFF              4330 non-null   float64
#  30  TxCnt               4330 non-null   float64
#  31  TxTfrCnt            4330 non-null   float64
#  32  TxTfrValAdjNtv      4330 non-null   float64
#  33  TxTfrValAdjUSD      3769 non-null   float64
#  34  TxTfrValMeanNtv     4072 non-null   float64
#  35  TxTfrValMeanUSD     3769 non-null   float64
#  36  TxTfrValMedNtv      4072 non-null   float64
#  37  TxTfrValMedUSD      3769 non-null   float64
#  38  TxTfrValNtv         4330 non-null   float64
#  39  TxTfrValUSD         3769 non-null   float64
#  40  VtyDayRet180d       3589 non-null   float64
#  41  VtyDayRet30d        3739 non-null   float64
#  42  VtyDayRet60d        3709 non-null   float64
# dtypes: float64(42), object(1)
# memory usage: 1.4+ MB

# %%
#The variable definitions for each column is in the 'metrics_info.csv' file.
metrics_info = pd.read_csv('../data/raw/metrics_info.csv').transpose()
#Here I also name the columns with the id row and "erase" the 'id' row.
metrics_info.columns = metrics_info.loc['id']
metrics_info = metrics_info.loc['name': 'description']
metrics_info
# Out:
# id                                                   AdrActCnt  \
# name                                  Addresses, active, count
# category                                             Addresses
# subcategory                                             Active
# type                                                       Sum
# unit                                                 Addresses
# interval                                                 1 day
# interval_rt                                            1 block
# description  The sum count of unique addresses that were ac...
#
# id                                                      BlkCnt  \
# name                                              Block, count
# category                                         Network Usage
# subcategory                                             Blocks
# type                                                       Sum
# unit                                                    Blocks
# interval                                                 1 day
# interval_rt                                                NaN
# description  The sum count of blocks created that interval ...
#
# id                                                 BlkSizeByte  \
# name                                        Block, size, bytes
# category                                         Network Usage
# subcategory                                             Blocks
# type                                                       Sum
# unit                                                     Bytes
# interval                                                 1 day
# interval_rt                                            1 block
# description  The sum of the size (in bytes) of all blocks c...
#
# id                                             BlkSizeMeanByte  \
# name                                  Block, size, mean, bytes
# category                                         Network Usage
# subcategory                                             Blocks
# type                                                      Mean
# unit                                                     Bytes
# interval                                                 1 day
# interval_rt                                                NaN
# description  The mean size (in bytes) of all blocks created...
#
# id                                                  CapMVRVCur  \
# name                      Capitalization, MVRV, current supply
# category                                                Market
# subcategory                              Market Capitalization
# type                                                     Ratio
# unit                                             Dimensionless
# interval                                                 1 day
# interval_rt                                                NaN
# description  The ratio of the sum USD value of the current ...
#
# id                                               CapMrktCurUSD  \
# name               Capitalization, market, current supply, USD
# category                                                Market
# subcategory                              Market Capitalization
# type                                                   Product
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                                NaN
# description  The sum USD value of the current supply. Also ...
#
# id                                                  CapRealUSD  \
# name                             Capitalization, realized, USD
# category                                                Market
# subcategory                              Market Capitalization
# type                                                   Product
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                                NaN
# description  The sum USD value based on the USD closing pri...
#
# id                                                    DiffMean  \
# name                                          Difficulty, mean
# category                                                Mining
# subcategory                                         Difficulty
# type                                                      Mean
# unit                                             Dimensionless
# interval                                                 1 day
# interval_rt                                            1 block
# description  The mean difficulty of finding a hash that mee...
#
# id                                                  FeeMeanNtv  \
# name                     Fees, transaction, mean, native units
# category                                      Fees and Revenue
# subcategory                                               Fees
# type                                                      Mean
# unit                                              Native units
# interval                                                 1 day
# interval_rt                                            1 block
# description  The mean fee per transaction in native units t...
#
# id                                                  FeeMeanUSD  ...  \
# name                              Fees, transaction, mean, USD  ...
# category                                      Fees and Revenue  ...
# subcategory                                               Fees  ...
# type                                                      Mean  ...
# unit                                                       USD  ...
# interval                                                 1 day  ...
# interval_rt                                            1 block  ...
# description  The USD value of the mean fee per transaction ...  ...
#
# id                                              TxTfrValAdjUSD  \
# name             Transactions, transfers, value, adjusted, USD
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                       Sum
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                                NaN
# description  The USD value of the sum of native units trans...
#
# id                                             TxTfrValMeanNtv  \
# name         Transactions, transfers, value, mean, native u...
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                      Mean
# unit                                              Native units
# interval                                                 1 day
# interval_rt                                            1 block
# description  The mean count of native units transferred per...
#
# id                                             TxTfrValMeanUSD  \
# name                 Transactions, transfers, value, mean, USD
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                      Mean
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                            1 block
# description  The sum USD value of native units transferred ...
#
# id                                              TxTfrValMedNtv  \
# name         Transactions, transfers, value, median, native...
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                    Median
# unit                                              Native units
# interval                                                 1 day
# interval_rt                                            1 block
# description  The median count of native units transferred p...
#
# id                                              TxTfrValMedUSD  \
# name               Transactions, transfers, value, median, USD
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                    Median
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                            1 block
# description  The median USD value transferred per transfer ...
#
# id                                                 TxTfrValNtv  \
# name              Transactions, transfers, value, native units
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                       Sum
# unit                                              Native units
# interval                                                 1 day
# interval_rt                                            1 block
# description  The sum of native units transferred (i.e., the...
#
# id                                                 TxTfrValUSD  \
# name                       Transactions, transfers, value, USD
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                       Sum
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                            1 block
# description  The sum USD value of all native units transfer...
#
# id                                               VtyDayRet180d  \
# name                           Volatility, daily returns, 180d
# category                                                Market
# subcategory                                         Volatility
# type                                                     Ratio
# unit                                             Dimensionless
# interval                                              180 days
# interval_rt                                                NaN
# description  The 180D volatility, measured as the standard ...
#
# id                                                VtyDayRet30d  \
# name                            Volatility, daily returns, 30d
# category                                                Market
# subcategory                                         Volatility
# type                                                     Ratio
# unit                                             Dimensionless
# interval                                               30 days
# interval_rt                                                NaN
# description  The 30D volatility, measured as the standard d...
#
# id                                                VtyDayRet60d
# name                            Volatility, daily returns, 60d
# category                                                Market
# subcategory                                         Volatility
# type                                                     Ratio
# unit                                             Dimensionless
# interval                                               60 days
# interval_rt                                                NaN
# description  The 60D volatility, measured as the standard d...
#
# [8 rows x 42 columns]

# %%
#null values of PriceUSD column
Counter(pd.isnull(raw_data['PriceUSD']))
# Out:
# Counter({True: 561, False: 3769})

# %%
#Sumamry statistics
raw_data.describe()
# Out:
#           AdrActCnt       BlkCnt   BlkSizeByte  BlkSizeMeanByte   CapMVRVCur  \
# count  4.330000e+03  4330.000000  4.330000e+03     4.324000e+03  3769.000000
# mean   3.383651e+05   151.587067  7.149229e+07     4.792999e+05     2.031805
# std    3.311939e+05    35.403687  6.588364e+07     4.464033e+05     3.023574
# min    0.000000e+00     0.000000  0.000000e+00     2.150000e+02     0.386829
# 25%    1.656425e+04   138.000000  3.241284e+06     2.184012e+04     1.240100
# 50%    2.225800e+05   152.000000  4.898056e+07     3.316515e+05     1.667238
# 75%    6.375485e+05   166.000000  1.345976e+08     9.240319e+05     2.212735
# max    1.290363e+06   692.000000  2.565337e+08     1.427240e+06   146.038332
#
#        CapMrktCurUSD    CapRealUSD      DiffMean   FeeMeanNtv   FeeMeanUSD  \
# count   3.769000e+03  4.330000e+03  4.324000e+03  4072.000000  3769.000000
# mean    4.851244e+10  2.595037e+10  2.460548e+12     0.000925     1.114963
# std     7.007499e+10  3.995463e+10  4.843949e+12     0.007782     3.733993
# min     1.776705e+05  0.000000e+00  1.000000e+00     0.000000     0.000000
# 25%     2.906484e+08  4.298039e+07  1.508590e+06     0.000138     0.031513
# 50%     6.784553e+09  4.162657e+09  4.000747e+10     0.000232     0.110061
# 75%     9.686022e+10  4.494977e+10  1.452840e+12     0.000683     0.736640
# max     3.288988e+11  1.272300e+11  1.999734e+13     0.220000    56.308124
#
#        ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  \
# count  ...    3.769000e+03      4072.000000      3769.000000    4.072000e+03
# mean   ...    7.950752e+08        96.014314      3988.684501    5.532758e+01
# std    ...    1.238646e+09       681.177781      5440.745307    6.437846e+02
# min    ...    4.647065e+02         0.010000         0.762873    1.000000e-08
# 25%    ...    1.184692e+07         1.531606       520.349078    1.185987e-02
# 50%    ...    1.453767e+08         3.532049      1691.677007    2.875100e-02
# 75%    ...    1.384680e+09        21.870055      6184.369042    1.000000e-01
# max    ...    1.082210e+10     22175.000000     51124.770624    2.217500e+04
#
#        TxTfrValMedUSD   TxTfrValNtv   TxTfrValUSD  VtyDayRet180d  \
# count    3.769000e+03  4.330000e+03  3.769000e+03    3589.000000
# mean     3.735735e+01  1.052491e+06  2.479127e+09       0.048949
# std      5.176407e+01  1.924894e+06  4.357248e+09       0.021261
# min      8.203471e-08  0.000000e+00  5.874592e+02       0.020298
# 25%      3.376343e+00  3.575085e+05  4.789957e+07       0.032669
# 50%      1.474975e+01  6.790067e+05  5.448044e+08       0.042599
# 75%      6.576545e+01  1.284683e+06  3.824115e+09       0.059113
# max      5.348536e+02  6.725965e+07  4.877049e+10       0.109532
#
#        VtyDayRet30d  VtyDayRet60d
# count   3739.000000   3709.000000
# mean       0.043946      0.045987
# std        0.029767      0.026850
# min        0.007481      0.010406
# 25%        0.024657      0.027674
# 50%        0.035435      0.038446
# 75%        0.053277      0.057796
# max        0.191722      0.143269
#
# [8 rows x 42 columns]

# %%
#setting date column as index and droping it from columns
raw_data.index = pd.to_datetime(raw_data['time'])
raw_data = raw_data.drop('time', axis='columns')
raw_data.tail()
# Out:
#             AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# time
# 2020-11-06  1080743.0   153.0  194685185.0     1.272452e+06    2.299192
# 2020-11-07  1055012.0   146.0  198604086.0     1.360302e+06    2.187115
# 2020-11-08   920529.0   138.0  189145770.0     1.370622e+06    2.269764
# 2020-11-09  1188873.0   185.0  252934375.0     1.367213e+06    2.237517
# 2020-11-10  1026623.0   147.0  180843729.0     1.230229e+06    2.232287
#
#             CapMrktCurUSD    CapRealUSD      DiffMean  FeeMeanNtv  FeeMeanUSD  \
# time
# 2020-11-06   2.895100e+11  1.259182e+11  1.678778e+13    0.000684   10.684208
# 2020-11-07   2.755732e+11  1.259985e+11  1.678778e+13    0.000500    7.437259
# 2020-11-08   2.873323e+11  1.265912e+11  1.678778e+13    0.000384    5.955396
# 2020-11-09   2.840099e+11  1.269308e+11  1.678778e+13    0.000440    6.745236
# 2020-11-10   2.840139e+11  1.272300e+11  1.678778e+13    0.000507    7.768952
#
#             ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  \
# time        ...
# 2020-11-06  ...    5.377085e+09         0.798253     12467.889939
# 2020-11-07  ...    3.113639e+09         0.600304      8924.329906
# 2020-11-08  ...    2.807229e+09         0.637306      9878.241843
# 2020-11-09  ...    4.587933e+09         0.713117     10924.823338
# 2020-11-10  ...    4.678510e+09         0.739668     11331.173774
#
#             TxTfrValMedNtv  TxTfrValMedUSD    TxTfrValNtv   TxTfrValUSD  \
# time
# 2020-11-06        0.008849      138.219785  706950.322346  1.104184e+10
# 2020-11-07        0.006843      101.735828  444455.314929  6.607431e+09
# 2020-11-08        0.006680      103.540005  420998.539315  6.525478e+09
# 2020-11-09        0.008200      125.622524  603186.409034  9.240707e+09
# 2020-11-10        0.008271      126.700214  620125.585166  9.499875e+09
#
#             VtyDayRet180d  VtyDayRet30d  VtyDayRet60d
# time
# 2020-11-06       0.025758      0.024822      0.022120
# 2020-11-07       0.026023      0.027211      0.022916
# 2020-11-08       0.026128      0.027797      0.023359
# 2020-11-09       0.025851      0.028047      0.023476
# 2020-11-10       0.025607      0.028102      0.023490
#
# [5 rows x 42 columns]

# %%
#drop rows in 'PriceUSD' with NaN values
data = raw_data.dropna(subset=['PriceUSD'])
data.head()
# Out:
#             AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# time
# 2010-07-18      860.0   172.0     136889.0       795.866279  146.038332
# 2010-07-19      929.0   174.0     139254.0       800.310345   62.565130
# 2010-07-20      936.0   181.0     197425.0      1090.745856   45.106630
# 2010-07-21      784.0   207.0     124991.0       603.821256   38.357560
# 2010-07-22      594.0   176.0     100750.0       572.443182   25.132348
#
#             CapMrktCurUSD   CapRealUSD    DiffMean  FeeMeanNtv  FeeMeanUSD  \
# time
# 2010-07-18  295959.152000  2026.585401  181.543289    0.003185    0.000273
# 2010-07-19  279285.200000  4463.911468  181.543289    0.000150    0.000012
# 2010-07-20  259000.404990  5741.958660  181.543289    0.000000    0.000000
# 2010-07-21  275266.471297  7176.328942  181.543289    0.000000    0.000000
# 2010-07-22  203749.573975  8107.064743  181.543289    0.000000    0.000000
#
#             ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  \
# time        ...
# 2010-07-18  ...     1474.778412        48.783737         4.187596
# 2010-07-19  ...     3251.693384        86.951152         7.025653
# 2010-07-20  ...     1200.497201        42.528835         3.178423
# 2010-07-21  ...     1649.915979        71.822334         5.687816
# 2010-07-22  ...     1932.368865       112.714622         6.590397
#
#             TxTfrValMedNtv  TxTfrValMedUSD  TxTfrValNtv  TxTfrValUSD  \
# time
# 2010-07-18           1.850        0.158804     19318.36  1658.288022
# 2010-07-19           2.625        0.212100     44518.99  3597.134392
# 2010-07-20           1.375        0.102762     31386.28  2345.676511
# 2010-07-21          18.500        1.465068     27077.02  2144.306726
# 2010-07-22           1.010        0.059054     38773.83  2267.096549
#
#             VtyDayRet180d  VtyDayRet30d  VtyDayRet60d
# time
# 2010-07-18            NaN           NaN           NaN
# 2010-07-19            NaN           NaN           NaN
# 2010-07-20            NaN           NaN           NaN
# 2010-07-21            NaN           NaN           NaN
# 2010-07-22            NaN           NaN           NaN
#
# [5 rows x 42 columns]

# %%
data.describe()
# Out:
#           AdrActCnt       BlkCnt   BlkSizeByte  BlkSizeMeanByte   CapMVRVCur  \
# count  3.769000e+03  3769.000000  3.769000e+03     3.769000e+03  3769.000000
# mean   3.887000e+05   155.900239  8.212771e+07     5.498380e+05     2.031805
# std    3.262822e+05    23.711154  6.413768e+07     4.357207e+05     3.023574
# min    4.080000e+02    80.000000  7.103500e+04     4.164167e+02     0.386829
# 25%    5.420800e+04   141.000000  2.016676e+07     1.214581e+05     1.240100
# 50%    3.146240e+05   153.000000  7.849033e+07     5.189138e+05     1.667238
# 75%    6.693730e+05   166.000000  1.410928e+08     9.624068e+05     2.212735
# max    1.290363e+06   307.000000  2.565337e+08     1.427240e+06   146.038332
#
#        CapMrktCurUSD    CapRealUSD      DiffMean   FeeMeanNtv   FeeMeanUSD  \
# count   3.769000e+03  3.769000e+03  3.769000e+03  3769.000000  3769.000000
# mean    4.851244e+10  2.981298e+10  2.822873e+12     0.000559     1.114963
# std     7.007499e+10  4.145917e+10  5.088893e+12     0.001303     3.733993
# min     1.776705e+05  2.026585e+03  1.815433e+02     0.000000     0.000000
# 25%     2.906484e+08  1.043909e+08  3.438909e+06     0.000152     0.031513
# 50%     6.784553e+09  4.568824e+09  5.695765e+10     0.000262     0.110061
# 75%     9.686022e+10  7.812905e+10  3.511061e+12     0.000713     0.736640
# max     3.288988e+11  1.272300e+11  1.999734e+13     0.043644    56.308124
#
#        ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  \
# count  ...    3.769000e+03      3769.000000      3769.000000    3.769000e+03
# mean   ...    7.950752e+08        22.620299      3988.684501    7.497312e-01
# std    ...    1.238646e+09        72.100325      5440.745307    5.013828e+00
# min    ...    4.647065e+02         0.400728         0.762873    1.000000e-08
# 25%    ...    1.184692e+07         1.413906       520.349078    1.130308e-02
# 50%    ...    1.453767e+08         3.203656      1691.677007    2.533827e-02
# 75%    ...    1.384680e+09        13.139090      6184.369042    5.852079e-02
# max    ...    1.082210e+10      1412.355198     51124.770624    1.000000e+02
#
#        TxTfrValMedUSD   TxTfrValNtv   TxTfrValUSD  VtyDayRet180d  \
# count    3.769000e+03  3.769000e+03  3.769000e+03    3589.000000
# mean     3.735735e+01  1.207476e+06  2.479127e+09       0.048949
# std      5.176407e+01  2.017323e+06  4.357248e+09       0.021261
# min      8.203471e-08  9.179050e+03  5.874592e+02       0.020298
# 25%      3.376343e+00  5.155127e+05  4.789957e+07       0.032669
# 50%      1.474975e+01  7.806925e+05  5.448044e+08       0.042599
# 75%      6.576545e+01  1.401861e+06  3.824115e+09       0.059113
# max      5.348536e+02  6.725965e+07  4.877049e+10       0.109532
#
#        VtyDayRet30d  VtyDayRet60d
# count   3739.000000   3709.000000
# mean       0.043946      0.045987
# std        0.029767      0.026850
# min        0.007481      0.010406
# 25%        0.024657      0.027674
# 50%        0.035435      0.038446
# 75%        0.053277      0.057796
# max        0.191722      0.143269
#
# [8 rows x 42 columns]

# %%
#Most variables have now 100% non-null values.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3769 entries, 2010-07-18 to 2020-11-10
# Data columns (total 42 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   AdrActCnt           3769 non-null   float64
#  1   BlkCnt              3769 non-null   float64
#  2   BlkSizeByte         3769 non-null   float64
#  3   BlkSizeMeanByte     3769 non-null   float64
#  4   CapMVRVCur          3769 non-null   float64
#  5   CapMrktCurUSD       3769 non-null   float64
#  6   CapRealUSD          3769 non-null   float64
#  7   DiffMean            3769 non-null   float64
#  8   FeeMeanNtv          3769 non-null   float64
#  9   FeeMeanUSD          3769 non-null   float64
#  10  FeeMedNtv           3769 non-null   float64
#  11  FeeMedUSD           3769 non-null   float64
#  12  FeeTotNtv           3769 non-null   float64
#  13  FeeTotUSD           3769 non-null   float64
#  14  HashRate            3769 non-null   float64
#  15  IssContNtv          3769 non-null   float64
#  16  IssContPctAnn       3769 non-null   float64
#  17  IssContUSD          3769 non-null   float64
#  18  IssTotNtv           3769 non-null   float64
#  19  IssTotUSD           3769 non-null   float64
#  20  NVTAdj              3769 non-null   float64
#  21  NVTAdj90            3680 non-null   float64
#  22  PriceBTC            3769 non-null   float64
#  23  PriceUSD            3769 non-null   float64
#  24  ROI1yr              3404 non-null   float64
#  25  ROI30d              3739 non-null   float64
#  26  SplyCur             3769 non-null   float64
#  27  SplyExpFut10yrCMBI  3769 non-null   float64
#  28  SplyFF              3769 non-null   float64
#  29  TxCnt               3769 non-null   float64
#  30  TxTfrCnt            3769 non-null   float64
#  31  TxTfrValAdjNtv      3769 non-null   float64
#  32  TxTfrValAdjUSD      3769 non-null   float64
#  33  TxTfrValMeanNtv     3769 non-null   float64
#  34  TxTfrValMeanUSD     3769 non-null   float64
#  35  TxTfrValMedNtv      3769 non-null   float64
#  36  TxTfrValMedUSD      3769 non-null   float64
#  37  TxTfrValNtv         3769 non-null   float64
#  38  TxTfrValUSD         3769 non-null   float64
#  39  VtyDayRet180d       3589 non-null   float64
#  40  VtyDayRet30d        3739 non-null   float64
#  41  VtyDayRet60d        3709 non-null   float64
# dtypes: float64(42)
# memory usage: 1.2 MB

# %%
#Most columns have now 100% non-null values.
#Columns with less than 100% non-null values are data whose calculation depends on trailing moving averages
#of 30-365 days. These values will be set to zero.
data_pct_non_null = data.count()/len(data)*100
data_pct_non_null
# Out:
# AdrActCnt             100.000000
# BlkCnt                100.000000
# BlkSizeByte           100.000000
# BlkSizeMeanByte       100.000000
# CapMVRVCur            100.000000
# CapMrktCurUSD         100.000000
# CapRealUSD            100.000000
# DiffMean              100.000000
# FeeMeanNtv            100.000000
# FeeMeanUSD            100.000000
# FeeMedNtv             100.000000
# FeeMedUSD             100.000000
# FeeTotNtv             100.000000
# FeeTotUSD             100.000000
# HashRate              100.000000
# IssContNtv            100.000000
# IssContPctAnn         100.000000
# IssContUSD            100.000000
# IssTotNtv             100.000000
# IssTotUSD             100.000000
# NVTAdj                100.000000
# NVTAdj90               97.638631
# PriceBTC              100.000000
# PriceUSD              100.000000
# ROI1yr                 90.315734
# ROI30d                 99.204033
# SplyCur               100.000000
# SplyExpFut10yrCMBI    100.000000
# SplyFF                100.000000
# TxCnt                 100.000000
# TxTfrCnt              100.000000
# TxTfrValAdjNtv        100.000000
# TxTfrValAdjUSD        100.000000
# TxTfrValMeanNtv       100.000000
# TxTfrValMeanUSD       100.000000
# TxTfrValMedNtv        100.000000
# TxTfrValMedUSD        100.000000
# TxTfrValNtv           100.000000
# TxTfrValUSD           100.000000
# VtyDayRet180d          95.224197
# VtyDayRet30d           99.204033
# VtyDayRet60d           98.408066
# dtype: float64

# %%
#replacing non-null values with zeros.
data = data.fillna(0)
data.head()
data_pct_non_null = data.count()/len(data)*100
data_pct_non_null
# Out:
# AdrActCnt             100.0
# BlkCnt                100.0
# BlkSizeByte           100.0
# BlkSizeMeanByte       100.0
# CapMVRVCur            100.0
# CapMrktCurUSD         100.0
# CapRealUSD            100.0
# DiffMean              100.0
# FeeMeanNtv            100.0
# FeeMeanUSD            100.0
# FeeMedNtv             100.0
# FeeMedUSD             100.0
# FeeTotNtv             100.0
# FeeTotUSD             100.0
# HashRate              100.0
# IssContNtv            100.0
# IssContPctAnn         100.0
# IssContUSD            100.0
# IssTotNtv             100.0
# IssTotUSD             100.0
# NVTAdj                100.0
# NVTAdj90              100.0
# PriceBTC              100.0
# PriceUSD              100.0
# ROI1yr                100.0
# ROI30d                100.0
# SplyCur               100.0
# SplyExpFut10yrCMBI    100.0
# SplyFF                100.0
# TxCnt                 100.0
# TxTfrCnt              100.0
# TxTfrValAdjNtv        100.0
# TxTfrValAdjUSD        100.0
# TxTfrValMeanNtv       100.0
# TxTfrValMeanUSD       100.0
# TxTfrValMedNtv        100.0
# TxTfrValMedUSD        100.0
# TxTfrValNtv           100.0
# TxTfrValUSD           100.0
# VtyDayRet180d         100.0
# VtyDayRet30d          100.0
# VtyDayRet60d          100.0
# dtype: float64

# %%
#Additional dataframes for monthly and annual data will be created to analyse in next stages
#if there are clearer paterns.
#agg_dict shows the agg fnction for each column in data.

agg_dict = {'AdrActCnt': 'mean', 'BlkCnt': 'sum', 'BlkSizeByte': 'sum', 'BlkSizeMeanByte': 'mean', 'CapMVRVCur': 'mean',
       'CapMrktCurUSD': 'mean', 'CapRealUSD': 'mean', 'DiffMean': 'mean', 'FeeMeanNtv': 'mean', 'FeeMeanUSD': 'mean',
       'FeeMedNtv': 'mean', 'FeeMedUSD': 'mean', 'FeeTotNtv': 'sum', 'FeeTotUSD': 'sum', 'HashRate': 'mean',
       'IssContNtv': 'sum', 'IssContPctAnn': 'mean', 'IssContUSD': 'sum', 'IssTotNtv': 'sum', 'IssTotUSD': 'sum',
       'NVTAdj': 'mean', 'NVTAdj90': 'mean', 'PriceBTC': 'mean', 'PriceUSD': 'mean', 'ROI1yr': 'mean', 'ROI30d': 'mean',
       'SplyCur': lambda x: x.iloc[-1], 'SplyExpFut10yrCMBI': lambda x: x.iloc[-1], 'SplyFF': lambda x: x.iloc[-1], 'TxCnt': 'sum',
       'TxTfrCnt': 'sum', 'TxTfrValAdjNtv': 'sum' , 'TxTfrValAdjUSD': 'sum', 'TxTfrValMeanNtv': 'mean',
       'TxTfrValMeanUSD': 'mean', 'TxTfrValMedNtv': 'mean', 'TxTfrValMedUSD': 'mean', 'TxTfrValNtv': 'sum',
       'TxTfrValUSD': 'sum', 'VtyDayRet180d': 'mean', 'VtyDayRet30d': 'mean', 'VtyDayRet60d': 'mean'}
    
#resample data by month.
monthly_data = data.resample('M').agg(agg_dict)
monthly_data.tail()
# Out:
#                AdrActCnt  BlkCnt   BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# time
# 2020-07-31  9.579079e+05  4589.0  5.634141e+09     1.231561e+06    1.637557
# 2020-08-31  9.836875e+05  4521.0  5.763779e+09     1.275403e+06    1.906278
# 2020-09-30  9.813088e+05  4531.0  5.610316e+09     1.240624e+06    1.710163
# 2020-10-31  9.420100e+05  4201.0  5.250980e+09     1.253807e+06    1.867554
# 2020-11-30  1.022307e+06  1435.0  1.879758e+09     1.308258e+06    2.189561
#
#             CapMrktCurUSD    CapRealUSD      DiffMean  FeeMeanNtv  FeeMeanUSD  \
# time
# 2020-07-31   1.769234e+11  1.079999e+11  1.665207e+13    0.000248    2.456221
# 2020-08-31   2.150555e+11  1.128243e+11  1.706749e+13    0.000341    3.971937
# 2020-09-30   1.968752e+11  1.151173e+11  1.811011e+13    0.000258    2.742665
# 2020-10-31   2.202892e+11  1.178209e+11  1.962374e+13    0.000384    4.759958
# 2020-11-30   2.737493e+11  1.249639e+11  1.752598e+13    0.000645    9.457670
#
#             ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  \
# time        ...
# 2020-07-31  ...    6.612761e+10         0.650288      6275.266298
# 2020-08-31  ...    8.099134e+10         0.663137      7731.114218
# 2020-09-30  ...    7.768880e+10         0.642011      6833.657834
# 2020-10-31  ...    9.209141e+10         0.689157      8245.459202
# 2020-11-30  ...    4.631057e+10         0.780397     11500.188963
#
#             TxTfrValMedNtv  TxTfrValMedUSD   TxTfrValNtv   TxTfrValUSD  \
# time
# 2020-07-31        0.011108      106.585636  1.663326e+07  1.608771e+11
# 2020-08-31        0.009346      108.847766  1.712498e+07  1.995972e+11
# 2020-09-30        0.009986      106.267283  1.621817e+07  1.727771e+11
# 2020-10-31        0.009388      111.542235  1.708541e+07  2.038261e+11
# 2020-11-30        0.008479      125.113248  6.259168e+06  9.245327e+10
#
#             VtyDayRet180d  VtyDayRet30d  VtyDayRet60d
# time
# 2020-07-31       0.050425      0.017046      0.025692
# 2020-08-31       0.050518      0.026793      0.022812
# 2020-09-30       0.035837      0.027899      0.027670
# 2020-10-31       0.027740      0.018368      0.023847
# 2020-11-30       0.026074      0.023654      0.021791
#
# [5 rows x 42 columns]

# %%
#resample data by year.
annual_data = data.resample('A').agg(agg_dict)
annual_data
# Out:
#                 AdrActCnt   BlkCnt   BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# time
# 2010-12-31     833.514970  31630.0  3.788206e+07     1.297562e+03    7.090611
# 2011-12-31   12295.013699  59627.0  8.018074e+08     1.420473e+04    2.479248
# 2012-12-31   30146.677596  54526.0  3.797173e+09     7.034127e+04    1.423834
# 2013-12-31   82843.408219  63433.0  9.385366e+09     1.500106e+05    2.685971
# 2014-12-31  181478.969863  58865.0  1.452069e+10     2.516785e+05    1.594508
# 2015-12-31  301076.126027  54321.0  2.604091e+10     4.801743e+05    0.936284
# 2016-12-31  515345.180328  54851.0  4.258150e+10     7.816624e+05    1.609995
# 2017-12-31  755832.079452  55928.0  5.292733e+10     9.492896e+05    2.705348
# 2018-12-31  665700.956164  54498.0  4.799031e+10     8.881502e+05    1.453296
# 2019-12-31  716083.471233  54232.0  5.803817e+10     1.074397e+06    1.436337
# 2020-12-31  870263.193651  45677.0  5.341820e+10     1.175886e+06    1.625863
#
#             CapMrktCurUSD    CapRealUSD      DiffMean  FeeMeanNtv  FeeMeanUSD  \
# time
# 2010-12-31   6.331603e+05  1.541879e+05  3.649643e+03    0.000612    0.000060
# 2011-12-31   3.861201e+07  2.610272e+07  8.621567e+05    0.001543    0.010471
# 2012-12-31   7.993273e+07  5.353516e+07  2.121159e+06    0.000943    0.007473
# 2013-12-31   2.228718e+09  7.489202e+08  1.637818e+08    0.000788    0.103297
# 2014-12-31   6.757827e+09  4.324092e+09  1.834246e+10    0.000187    0.100648
# 2015-12-31   3.928211e+09  4.179608e+09  5.436260e+10    0.000178    0.048629
# 2016-12-31   8.926094e+09  5.458429e+09  2.046476e+11    0.000268    0.158407
# 2017-12-31   6.626436e+10  2.217930e+10  8.291204e+11    0.000956    4.874578
# 2018-12-31   1.283610e+11  8.781141e+10  4.970596e+12    0.000278    2.897676
# 2019-12-31   1.314117e+11  8.967253e+10  8.995568e+12    0.000159    1.242841
# 2020-12-31   1.771922e+11  1.082028e+11  1.630994e+13    0.000226    2.396987
#
#             ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  \
# time        ...
# 2010-12-31  ...    1.105034e+06       195.392381        27.108394
# 2011-12-31  ...    4.673696e+08        69.041664       348.426814
# 2012-12-31  ...    9.105038e+08        48.716734       419.353287
# 2013-12-31  ...    2.197955e+10         8.829844      1518.834127
# 2014-12-31  ...    3.435196e+10         3.207021      1725.361838
# 2015-12-31  ...    3.241331e+10         3.897498      1127.893510
# 2016-12-31  ...    8.794020e+10         4.782689      2426.564665
# 2017-12-31  ...    6.713100e+11         2.599866     10133.203211
# 2018-12-31  ...    7.534700e+11         1.310201     10096.028805
# 2019-12-31  ...    6.730847e+11         0.978231      7063.936384
# 2020-12-31  ...    7.207100e+11         0.774959      7308.647300
#
#             TxTfrValMedNtv  TxTfrValMedUSD   TxTfrValNtv   TxTfrValUSD  \
# time
# 2010-12-31       13.302784        1.826968  1.289854e+07  1.935703e+06
# 2011-12-31        1.150084        4.115153  2.926536e+08  2.509709e+09
# 2012-12-31        0.319891        1.926208  8.988208e+08  8.810182e+09
# 2013-12-31        0.048970        9.281768  3.869203e+08  8.136131e+10
# 2014-12-31        0.031913       16.619881  2.202999e+08  1.150737e+11
# 2015-12-31        0.024360        6.906548  4.914099e+08  1.491670e+11
# 2016-12-31        0.025398       14.308969  9.042906e+08  4.626165e+11
# 2017-12-31        0.021645       75.887161  6.370922e+08  2.763896e+12
# 2018-12-31        0.012467       98.985158  2.663874e+08  2.117775e+12
# 2019-12-31        0.010868       73.888608  2.565331e+08  1.887381e+12
# 2020-12-31        0.010107       96.120407  1.836711e+08  1.755236e+12
#
#             VtyDayRet180d  VtyDayRet30d  VtyDayRet60d
# time
# 2010-12-31       0.000000      0.059727      0.050218
# 2011-12-31       0.088670      0.082654      0.087593
# 2012-12-31       0.051386      0.035219      0.039004
# 2013-12-31       0.063635      0.058025      0.058482
# 2014-12-31       0.051602      0.039100      0.043846
# 2015-12-31       0.035214      0.032386      0.033617
# 2016-12-31       0.029502      0.023457      0.025207
# 2017-12-31       0.039583      0.044320      0.043977
# 2018-12-31       0.046992      0.041816      0.043065
# 2019-12-31       0.038540      0.035544      0.037223
# 2020-12-31       0.041676      0.034950      0.037239
#
# [11 rows x 42 columns]

# %%
annual_prices = annual_data['PriceUSD']
annual_prices
# Out:
# time
# 2010-12-31       0.140855
# 2011-12-31       5.641328
# 2012-12-31       8.291235
# 2013-12-31     188.857898
# 2014-12-31     525.173537
# 2015-12-31     272.880117
# 2016-12-31     568.197748
# 2017-12-31    3994.489110
# 2018-12-31    7519.170891
# 2019-12-31    7365.207125
# 2020-12-31    9635.796190
# Freq: A-DEC, Name: PriceUSD, dtype: float64

# %%
#The goal here is to create a column that accounts for the halving periods of bitcoin block subsidy.

#First we create the column 'block_height', which is the cumulative sum of blocks produced each day.
data['block_height'] = raw_data['BlkCnt'].cumsum(axis=0)
print(data['block_height'])

#We create the 'halving_period' column by dividing the 'block_height' by 210,000 
data['halving_period'] = data['block_height'].apply(lambda x: x // 210000)
data['halving_period']

#The 'halving_period' column will allow us to analize the data taking into account the halving periods.
# Out:
# time
# 2010-07-18     68956.0
# 2010-07-19     69130.0
# 2010-07-20     69311.0
# 2010-07-21     69518.0
# 2010-07-22     69694.0
#                 ...
# 2020-11-06    655756.0
# 2020-11-07    655902.0
# 2020-11-08    656040.0
# 2020-11-09    656225.0
# 2020-11-10    656372.0
# Name: block_height, Length: 3769, dtype: float64
# time
# 2010-07-18    0.0
# 2010-07-19    0.0
# 2010-07-20    0.0
# 2010-07-21    0.0
# 2010-07-22    0.0
#              ...
# 2020-11-06    3.0
# 2020-11-07    3.0
# 2020-11-08    3.0
# 2020-11-09    3.0
# 2020-11-10    3.0
# Name: halving_period, Length: 3769, dtype: float64
