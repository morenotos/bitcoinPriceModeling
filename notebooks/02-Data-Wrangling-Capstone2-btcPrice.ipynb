# %%
#importing packages.
import pandas as pd
from collections import Counter

# %%
#DATA COLLECTION - fetching raw database in csv format from url.
url = 'https://raw.githubusercontent.com/coinmetrics-io/data/master/csv/btc.csv'
raw_data = pd.read_csv(url)
raw_data.tail()
# Out:
#             time  AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# 4394  2021-01-14  1167975.0   147.0  190694607.0     1.297242e+06    3.439686
# 4395  2021-01-15  1209589.0   155.0  203959113.0     1.315865e+06    3.216919
# 4396  2021-01-16  1115276.0   147.0  193973217.0     1.319546e+06    3.160028
# 4397  2021-01-17  1002014.0   133.0  176557250.0     1.327498e+06    3.142090
# 4398  2021-01-18  1077578.0   145.0  194495781.0     1.341350e+06    3.167897
#
#       CapMrktCurUSD    CapRealUSD      DiffMean  FeeMeanNtv  ...  \
# 4394   7.262631e+11  2.111423e+11  2.060742e+13    0.000420  ...
# 4395   6.828629e+11  2.122724e+11  2.060742e+13    0.000424  ...
# 4396   6.729806e+11  2.129666e+11  2.060742e+13    0.000284  ...
# 4397   6.710141e+11  2.135566e+11  2.060742e+13    0.000240  ...
# 4398   6.808020e+11  2.149066e+11  2.060742e+13    0.000272  ...
#
#       TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  \
# 4394    1.398485e+10         0.755119     29484.008768        0.004877
# 4395    1.173362e+10         0.711617     26123.685484        0.004118
# 4396    6.424095e+09         0.483329     17485.508476        0.003200
# 4397    6.204050e+09         0.484291     17468.332893        0.003212
# 4398    7.852109e+09         0.593916     21733.955700        0.004121
#
#       TxTfrValMedUSD    TxTfrValNtv   TxTfrValUSD  VtyDayRet180d  \
# 4394      190.423041  716754.326954  2.798604e+10       0.032325
# 4395      151.172720  698293.382321  2.563457e+10       0.032739
# 4396      115.767959  429523.096686  1.553897e+10       0.032766
# 4397      115.841677  359411.915651  1.296397e+10       0.032753
# 4398      150.807657  506360.124532  1.852989e+10       0.032752
#
#       VtyDayRet30d  VtyDayRet60d
# 4394      0.046550      0.041402
# 4395      0.047006      0.042350
# 4396      0.046535      0.042143
# 4397      0.046651      0.042182
# 4398      0.046505      0.042159
#
# [5 rows x 43 columns]

# %%
#Info from raw_data
#43 columns and 4329 rows
#All columns are floats, except the first column 'time' (object type), which is the date.
#Column PriceUSD, the price of bitcoin in USD, has 3768 entries.
#For modeling purposes we may have to drop the rows where PriceUSD is null.
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4399 entries, 0 to 4398
# Data columns (total 43 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   time                4399 non-null   object
#  1   AdrActCnt           4399 non-null   float64
#  2   BlkCnt              4399 non-null   float64
#  3   BlkSizeByte         4399 non-null   float64
#  4   BlkSizeMeanByte     4393 non-null   float64
#  5   CapMVRVCur          3838 non-null   float64
#  6   CapMrktCurUSD       3838 non-null   float64
#  7   CapRealUSD          4399 non-null   float64
#  8   DiffMean            4393 non-null   float64
#  9   FeeMeanNtv          4141 non-null   float64
#  10  FeeMeanUSD          3838 non-null   float64
#  11  FeeMedNtv           4141 non-null   float64
#  12  FeeMedUSD           3838 non-null   float64
#  13  FeeTotNtv           4399 non-null   float64
#  14  FeeTotUSD           3838 non-null   float64
#  15  HashRate            4393 non-null   float64
#  16  IssContNtv          4393 non-null   float64
#  17  IssContPctAnn       4393 non-null   float64
#  18  IssContUSD          3838 non-null   float64
#  19  IssTotNtv           4393 non-null   float64
#  20  IssTotUSD           3838 non-null   float64
#  21  NVTAdj              4139 non-null   float64
#  22  NVTAdj90            3749 non-null   float64
#  23  PriceBTC            4399 non-null   float64
#  24  PriceUSD            3838 non-null   float64
#  25  ROI1yr              3473 non-null   float64
#  26  ROI30d              3808 non-null   float64
#  27  SplyCur             4399 non-null   float64
#  28  SplyExpFut10yrCMBI  4393 non-null   float64
#  29  SplyFF              4399 non-null   float64
#  30  TxCnt               4399 non-null   float64
#  31  TxTfrCnt            4399 non-null   float64
#  32  TxTfrValAdjNtv      4399 non-null   float64
#  33  TxTfrValAdjUSD      3838 non-null   float64
#  34  TxTfrValMeanNtv     4141 non-null   float64
#  35  TxTfrValMeanUSD     3838 non-null   float64
#  36  TxTfrValMedNtv      4141 non-null   float64
#  37  TxTfrValMedUSD      3838 non-null   float64
#  38  TxTfrValNtv         4399 non-null   float64
#  39  TxTfrValUSD         3838 non-null   float64
#  40  VtyDayRet180d       3658 non-null   float64
#  41  VtyDayRet30d        3808 non-null   float64
#  42  VtyDayRet60d        3778 non-null   float64
# dtypes: float64(42), object(1)
# memory usage: 1.4+ MB

# %%
#The variable definitions for each column is in the 'metrics_info.csv' file.
metrics_info = pd.read_csv('../data/raw/metrics_info.csv').transpose()
#Here I also name the columns with the id row and "erase" the 'id' row.
metrics_info.columns = metrics_info.loc['id']
metrics_info = metrics_info.loc['name': 'description']
metrics_info
# Out:
# id                                                   AdrActCnt  \
# name                                  Addresses, active, count
# category                                             Addresses
# subcategory                                             Active
# type                                                       Sum
# unit                                                 Addresses
# interval                                                 1 day
# interval_rt                                            1 block
# description  The sum count of unique addresses that were ac...
#
# id                                                      BlkCnt  \
# name                                              Block, count
# category                                         Network Usage
# subcategory                                             Blocks
# type                                                       Sum
# unit                                                    Blocks
# interval                                                 1 day
# interval_rt                                                NaN
# description  The sum count of blocks created that interval ...
#
# id                                                 BlkSizeByte  \
# name                                        Block, size, bytes
# category                                         Network Usage
# subcategory                                             Blocks
# type                                                       Sum
# unit                                                     Bytes
# interval                                                 1 day
# interval_rt                                            1 block
# description  The sum of the size (in bytes) of all blocks c...
#
# id                                             BlkSizeMeanByte  \
# name                                  Block, size, mean, bytes
# category                                         Network Usage
# subcategory                                             Blocks
# type                                                      Mean
# unit                                                     Bytes
# interval                                                 1 day
# interval_rt                                                NaN
# description  The mean size (in bytes) of all blocks created...
#
# id                                                  CapMVRVCur  \
# name                      Capitalization, MVRV, current supply
# category                                                Market
# subcategory                              Market Capitalization
# type                                                     Ratio
# unit                                             Dimensionless
# interval                                                 1 day
# interval_rt                                                NaN
# description  The ratio of the sum USD value of the current ...
#
# id                                               CapMrktCurUSD  \
# name               Capitalization, market, current supply, USD
# category                                                Market
# subcategory                              Market Capitalization
# type                                                   Product
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                                NaN
# description  The sum USD value of the current supply. Also ...
#
# id                                                  CapRealUSD  \
# name                             Capitalization, realized, USD
# category                                                Market
# subcategory                              Market Capitalization
# type                                                   Product
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                                NaN
# description  The sum USD value based on the USD closing pri...
#
# id                                                    DiffMean  \
# name                                          Difficulty, mean
# category                                                Mining
# subcategory                                         Difficulty
# type                                                      Mean
# unit                                             Dimensionless
# interval                                                 1 day
# interval_rt                                            1 block
# description  The mean difficulty of finding a hash that mee...
#
# id                                                  FeeMeanNtv  \
# name                     Fees, transaction, mean, native units
# category                                      Fees and Revenue
# subcategory                                               Fees
# type                                                      Mean
# unit                                              Native units
# interval                                                 1 day
# interval_rt                                            1 block
# description  The mean fee per transaction in native units t...
#
# id                                                  FeeMeanUSD  ...  \
# name                              Fees, transaction, mean, USD  ...
# category                                      Fees and Revenue  ...
# subcategory                                               Fees  ...
# type                                                      Mean  ...
# unit                                                       USD  ...
# interval                                                 1 day  ...
# interval_rt                                            1 block  ...
# description  The USD value of the mean fee per transaction ...  ...
#
# id                                              TxTfrValAdjUSD  \
# name             Transactions, transfers, value, adjusted, USD
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                       Sum
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                                NaN
# description  The USD value of the sum of native units trans...
#
# id                                             TxTfrValMeanNtv  \
# name         Transactions, transfers, value, mean, native u...
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                      Mean
# unit                                              Native units
# interval                                                 1 day
# interval_rt                                            1 block
# description  The mean count of native units transferred per...
#
# id                                             TxTfrValMeanUSD  \
# name                 Transactions, transfers, value, mean, USD
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                      Mean
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                            1 block
# description  The sum USD value of native units transferred ...
#
# id                                              TxTfrValMedNtv  \
# name         Transactions, transfers, value, median, native...
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                    Median
# unit                                              Native units
# interval                                                 1 day
# interval_rt                                            1 block
# description  The median count of native units transferred p...
#
# id                                              TxTfrValMedUSD  \
# name               Transactions, transfers, value, median, USD
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                    Median
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                            1 block
# description  The median USD value transferred per transfer ...
#
# id                                                 TxTfrValNtv  \
# name              Transactions, transfers, value, native units
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                       Sum
# unit                                              Native units
# interval                                                 1 day
# interval_rt                                            1 block
# description  The sum of native units transferred (i.e., the...
#
# id                                                 TxTfrValUSD  \
# name                       Transactions, transfers, value, USD
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                       Sum
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                            1 block
# description  The sum USD value of all native units transfer...
#
# id                                               VtyDayRet180d  \
# name                           Volatility, daily returns, 180d
# category                                                Market
# subcategory                                         Volatility
# type                                                     Ratio
# unit                                             Dimensionless
# interval                                              180 days
# interval_rt                                                NaN
# description  The 180D volatility, measured as the standard ...
#
# id                                                VtyDayRet30d  \
# name                            Volatility, daily returns, 30d
# category                                                Market
# subcategory                                         Volatility
# type                                                     Ratio
# unit                                             Dimensionless
# interval                                               30 days
# interval_rt                                                NaN
# description  The 30D volatility, measured as the standard d...
#
# id                                                VtyDayRet60d
# name                            Volatility, daily returns, 60d
# category                                                Market
# subcategory                                         Volatility
# type                                                     Ratio
# unit                                             Dimensionless
# interval                                               60 days
# interval_rt                                                NaN
# description  The 60D volatility, measured as the standard d...
#
# [8 rows x 42 columns]

# %%
#null values of PriceUSD column
Counter(pd.isnull(raw_data['PriceUSD']))
# Out:
# Counter({True: 561, False: 3838})

# %%
#Sumamry statistics
raw_data.describe()
# Out:
#           AdrActCnt       BlkCnt   BlkSizeByte  BlkSizeMeanByte   CapMVRVCur  \
# count  4.399000e+03  4399.000000  4.399000e+03     4.393000e+03  3838.000000
# mean   3.500817e+05   151.551944  7.336511e+07     4.918759e+05     2.045650
# std    3.416997e+05    35.159876  6.705668e+07     4.540093e+05     2.998505
# min    0.000000e+00     0.000000  0.000000e+00     2.150000e+02     0.386829
# 25%    1.746350e+04   138.000000  3.363856e+06     2.243067e+04     1.247405
# 50%    2.327780e+05   152.000000  5.138250e+07     3.550697e+05     1.684810
# 75%    6.491680e+05   166.000000  1.373763e+08     9.416373e+05     2.278163
# max    1.344921e+06   692.000000  2.565337e+08     1.427240e+06   146.038332
#
#        CapMrktCurUSD    CapRealUSD      DiffMean   FeeMeanNtv   FeeMeanUSD  \
# count   3.838000e+03  4.399000e+03  4.393000e+03  4141.000000  3838.000000
# mean    5.577707e+10  2.802258e+10  2.715101e+12     0.000915     1.229020
# std     8.983903e+10  4.303968e+10  5.212789e+12     0.007717     3.829182
# min     1.776705e+05  0.000000e+00  1.000000e+00     0.000000     0.000000
# 25%     3.802277e+08  4.345836e+07  1.563028e+06     0.000140     0.032310
# 50%     7.021311e+09  4.183654e+09  4.127287e+10     0.000235     0.113988
# 75%     1.085628e+11  7.644947e+10  2.227848e+12     0.000674     0.823386
# max     7.582106e+11  2.149066e+11  2.060742e+13     0.220000    56.308124
#
#        ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  \
# count  ...    3.838000e+03      4141.000000      3838.000000    4.141000e+03
# mean   ...    9.025315e+08        94.425348      4205.421046    5.440578e+01
# std    ...    1.522713e+09       675.587759      5685.058819    6.384364e+02
# min    ...    4.647065e+02         0.010000         0.762873    1.000000e-08
# 25%    ...    1.412271e+07         1.442738       532.730026    1.149473e-02
# 50%    ...    1.574260e+08         3.468442      1745.372789    2.794808e-02
# 75%    ...    1.459697e+09        21.281206      6540.175873    1.000000e-01
# max    ...    1.559867e+10     22175.000000     51124.770624    2.217500e+04
#
#        TxTfrValMedUSD   TxTfrValNtv   TxTfrValUSD  VtyDayRet180d  \
# count    3.838000e+03  4.399000e+03  3.838000e+03    3658.000000
# mean     3.921803e+01  1.044989e+06  2.692087e+09       0.048545
# std      5.323075e+01  1.910746e+06  4.683089e+09       0.021262
# min      8.203471e-08  0.000000e+00  5.874592e+02       0.020298
# 25%      3.556809e+00  3.613813e+05  5.505197e+07       0.032337
# 50%      1.511931e+01  6.760647e+05  5.934581e+08       0.042476
# 75%      6.817373e+01  1.267209e+06  4.017473e+09       0.058563
# max      5.348536e+02  6.725965e+07  4.877049e+10       0.109532
#
#        VtyDayRet30d  VtyDayRet60d
# count   3808.000000   3778.000000
# mean       0.043790      0.045728
# std        0.029525      0.026681
# min        0.007481      0.010406
# 25%        0.024765      0.027678
# 50%        0.035363      0.038044
# 75%        0.052523      0.056844
# max        0.191722      0.143269
#
# [8 rows x 42 columns]

# %%
#setting date column as index and droping it from columns
raw_data.index = pd.to_datetime(raw_data['time'])
raw_data = raw_data.drop('time', axis='columns')
raw_data.tail()
# Out:
#             AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# time
# 2021-01-14  1167975.0   147.0  190694607.0     1.297242e+06    3.439686
# 2021-01-15  1209589.0   155.0  203959113.0     1.315865e+06    3.216919
# 2021-01-16  1115276.0   147.0  193973217.0     1.319546e+06    3.160028
# 2021-01-17  1002014.0   133.0  176557250.0     1.327498e+06    3.142090
# 2021-01-18  1077578.0   145.0  194495781.0     1.341350e+06    3.167897
#
#             CapMrktCurUSD    CapRealUSD      DiffMean  FeeMeanNtv  FeeMeanUSD  \
# time
# 2021-01-14   7.262631e+11  2.111423e+11  2.060742e+13    0.000420   16.383083
# 2021-01-15   6.828629e+11  2.122724e+11  2.060742e+13    0.000424   15.561517
# 2021-01-16   6.729806e+11  2.129666e+11  2.060742e+13    0.000284   10.283218
# 2021-01-17   6.710141e+11  2.135566e+11  2.060742e+13    0.000240    8.652769
# 2021-01-18   6.808020e+11  2.149066e+11  2.060742e+13    0.000272    9.942728
#
#             ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  \
# time        ...
# 2021-01-14  ...    1.398485e+10         0.755119     29484.008768
# 2021-01-15  ...    1.173362e+10         0.711617     26123.685484
# 2021-01-16  ...    6.424095e+09         0.483329     17485.508476
# 2021-01-17  ...    6.204050e+09         0.484291     17468.332893
# 2021-01-18  ...    7.852109e+09         0.593916     21733.955700
#
#             TxTfrValMedNtv  TxTfrValMedUSD    TxTfrValNtv   TxTfrValUSD  \
# time
# 2021-01-14        0.004877      190.423041  716754.326954  2.798604e+10
# 2021-01-15        0.004118      151.172720  698293.382321  2.563457e+10
# 2021-01-16        0.003200      115.767959  429523.096686  1.553897e+10
# 2021-01-17        0.003212      115.841677  359411.915651  1.296397e+10
# 2021-01-18        0.004121      150.807657  506360.124532  1.852989e+10
#
#             VtyDayRet180d  VtyDayRet30d  VtyDayRet60d
# time
# 2021-01-14       0.032325      0.046550      0.041402
# 2021-01-15       0.032739      0.047006      0.042350
# 2021-01-16       0.032766      0.046535      0.042143
# 2021-01-17       0.032753      0.046651      0.042182
# 2021-01-18       0.032752      0.046505      0.042159
#
# [5 rows x 42 columns]

# %%
#drop rows in 'PriceUSD' with NaN values
data = raw_data.dropna(subset=['PriceUSD'])
data.head()
# Out:
#             AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# time
# 2010-07-18      860.0   172.0     136889.0       795.866279  146.038332
# 2010-07-19      929.0   174.0     139254.0       800.310345   62.565130
# 2010-07-20      936.0   181.0     197425.0      1090.745856   45.106630
# 2010-07-21      784.0   207.0     124991.0       603.821256   38.357560
# 2010-07-22      594.0   176.0     100750.0       572.443182   25.132348
#
#             CapMrktCurUSD   CapRealUSD    DiffMean  FeeMeanNtv  FeeMeanUSD  \
# time
# 2010-07-18  295959.152000  2026.585401  181.543289    0.003185    0.000273
# 2010-07-19  279285.200000  4463.911468  181.543289    0.000150    0.000012
# 2010-07-20  259000.404990  5741.958660  181.543289    0.000000    0.000000
# 2010-07-21  275266.471297  7176.328942  181.543289    0.000000    0.000000
# 2010-07-22  203749.573975  8107.064743  181.543289    0.000000    0.000000
#
#             ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  \
# time        ...
# 2010-07-18  ...     1474.778412        48.783737         4.187596
# 2010-07-19  ...     3251.693384        86.951152         7.025653
# 2010-07-20  ...     1200.497201        42.528835         3.178423
# 2010-07-21  ...     1649.915979        71.822334         5.687816
# 2010-07-22  ...     1932.368865       112.714622         6.590397
#
#             TxTfrValMedNtv  TxTfrValMedUSD  TxTfrValNtv  TxTfrValUSD  \
# time
# 2010-07-18           1.850        0.158804     19318.36  1658.288022
# 2010-07-19           2.625        0.212100     44518.99  3597.134392
# 2010-07-20           1.375        0.102762     31386.28  2345.676511
# 2010-07-21          18.500        1.465068     27077.02  2144.306726
# 2010-07-22           1.010        0.059054     38773.83  2267.096549
#
#             VtyDayRet180d  VtyDayRet30d  VtyDayRet60d
# time
# 2010-07-18            NaN           NaN           NaN
# 2010-07-19            NaN           NaN           NaN
# 2010-07-20            NaN           NaN           NaN
# 2010-07-21            NaN           NaN           NaN
# 2010-07-22            NaN           NaN           NaN
#
# [5 rows x 42 columns]

# %%
data.describe()
# Out:
#           AdrActCnt       BlkCnt   BlkSizeByte  BlkSizeMeanByte   CapMVRVCur  \
# count  3.838000e+03  3838.000000  3.838000e+03     3.838000e+03  3838.000000
# mean   4.012244e+05   155.782439  8.408307e+07     5.629644e+05     2.045650
# std    3.366226e+05    23.571136  6.521525e+07     4.426376e+05     2.998505
# min    4.080000e+02    80.000000  7.103500e+04     4.164167e+02     0.386829
# 25%    5.642150e+04   141.000000  2.083348e+07     1.243289e+05     1.247405
# 50%    3.510145e+05   153.000000  8.408638e+07     5.510705e+05     1.684810
# 75%    6.849058e+05   166.000000  1.429254e+08     9.708081e+05     2.278163
# max    1.344921e+06   307.000000  2.565337e+08     1.427240e+06   146.038332
#
#        CapMrktCurUSD    CapRealUSD      DiffMean   FeeMeanNtv   FeeMeanUSD  \
# count   3.838000e+03  3.838000e+03  3.838000e+03  3838.000000  3838.000000
# mean    5.577707e+10  3.211864e+10  3.107722e+12     0.000555     1.229020
# std     8.983903e+10  4.462800e+10  5.466547e+12     0.001292     3.829182
# min     1.776705e+05  2.026585e+03  1.815433e+02     0.000000     0.000000
# 25%     3.802277e+08  1.270068e+08  4.367876e+06     0.000153     0.032310
# 50%     7.021311e+09  4.581560e+09  6.088383e+10     0.000264     0.113988
# 75%     1.085628e+11  8.089262e+10  4.306950e+12     0.000701     0.823386
# max     7.582106e+11  2.149066e+11  2.060742e+13     0.043644    56.308124
#
#        ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  \
# count  ...    3.838000e+03      3838.000000      3838.000000    3.838000e+03
# mean   ...    9.025315e+08        22.225374      4205.421046    7.363622e-01
# std    ...    1.522713e+09        71.508712      5685.058819    4.969525e+00
# min    ...    4.647065e+02         0.400728         0.762873    1.000000e-08
# 25%    ...    1.412271e+07         1.329839       532.730026    1.100000e-02
# 50%    ...    1.574260e+08         3.144563      1745.372789    2.480291e-02
# 75%    ...    1.459697e+09        12.231863      6540.175873    5.603052e-02
# max    ...    1.559867e+10      1412.355198     51124.770624    1.000000e+02
#
#        TxTfrValMedUSD   TxTfrValNtv   TxTfrValUSD  VtyDayRet180d  \
# count    3.838000e+03  3.838000e+03  3.838000e+03    3658.000000
# mean     3.921803e+01  1.196092e+06  2.692087e+09       0.048545
# std      5.323075e+01  2.000968e+06  4.683089e+09       0.021262
# min      8.203471e-08  9.179050e+03  5.874592e+02       0.020298
# 25%      3.556809e+00  5.122827e+05  5.505197e+07       0.032337
# 50%      1.511931e+01  7.710148e+05  5.934581e+08       0.042476
# 75%      6.817373e+01  1.387461e+06  4.017473e+09       0.058563
# max      5.348536e+02  6.725965e+07  4.877049e+10       0.109532
#
#        VtyDayRet30d  VtyDayRet60d
# count   3808.000000   3778.000000
# mean       0.043790      0.045728
# std        0.029525      0.026681
# min        0.007481      0.010406
# 25%        0.024765      0.027678
# 50%        0.035363      0.038044
# 75%        0.052523      0.056844
# max        0.191722      0.143269
#
# [8 rows x 42 columns]

# %%
#Most variables have now 100% non-null values.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3838 entries, 2010-07-18 to 2021-01-18
# Data columns (total 42 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   AdrActCnt           3838 non-null   float64
#  1   BlkCnt              3838 non-null   float64
#  2   BlkSizeByte         3838 non-null   float64
#  3   BlkSizeMeanByte     3838 non-null   float64
#  4   CapMVRVCur          3838 non-null   float64
#  5   CapMrktCurUSD       3838 non-null   float64
#  6   CapRealUSD          3838 non-null   float64
#  7   DiffMean            3838 non-null   float64
#  8   FeeMeanNtv          3838 non-null   float64
#  9   FeeMeanUSD          3838 non-null   float64
#  10  FeeMedNtv           3838 non-null   float64
#  11  FeeMedUSD           3838 non-null   float64
#  12  FeeTotNtv           3838 non-null   float64
#  13  FeeTotUSD           3838 non-null   float64
#  14  HashRate            3838 non-null   float64
#  15  IssContNtv          3838 non-null   float64
#  16  IssContPctAnn       3838 non-null   float64
#  17  IssContUSD          3838 non-null   float64
#  18  IssTotNtv           3838 non-null   float64
#  19  IssTotUSD           3838 non-null   float64
#  20  NVTAdj              3838 non-null   float64
#  21  NVTAdj90            3749 non-null   float64
#  22  PriceBTC            3838 non-null   float64
#  23  PriceUSD            3838 non-null   float64
#  24  ROI1yr              3473 non-null   float64
#  25  ROI30d              3808 non-null   float64
#  26  SplyCur             3838 non-null   float64
#  27  SplyExpFut10yrCMBI  3838 non-null   float64
#  28  SplyFF              3838 non-null   float64
#  29  TxCnt               3838 non-null   float64
#  30  TxTfrCnt            3838 non-null   float64
#  31  TxTfrValAdjNtv      3838 non-null   float64
#  32  TxTfrValAdjUSD      3838 non-null   float64
#  33  TxTfrValMeanNtv     3838 non-null   float64
#  34  TxTfrValMeanUSD     3838 non-null   float64
#  35  TxTfrValMedNtv      3838 non-null   float64
#  36  TxTfrValMedUSD      3838 non-null   float64
#  37  TxTfrValNtv         3838 non-null   float64
#  38  TxTfrValUSD         3838 non-null   float64
#  39  VtyDayRet180d       3658 non-null   float64
#  40  VtyDayRet30d        3808 non-null   float64
#  41  VtyDayRet60d        3778 non-null   float64
# dtypes: float64(42)
# memory usage: 1.3 MB

# %%
#Most columns have now 100% non-null values.
#Columns with less than 100% non-null values are data whose calculation depends on trailing moving averages
#of 30-365 days. These values will be set to zero.
data_pct_non_null = data.count()/len(data)*100
data_pct_non_null
# Out:
# AdrActCnt             100.000000
# BlkCnt                100.000000
# BlkSizeByte           100.000000
# BlkSizeMeanByte       100.000000
# CapMVRVCur            100.000000
# CapMrktCurUSD         100.000000
# CapRealUSD            100.000000
# DiffMean              100.000000
# FeeMeanNtv            100.000000
# FeeMeanUSD            100.000000
# FeeMedNtv             100.000000
# FeeMedUSD             100.000000
# FeeTotNtv             100.000000
# FeeTotUSD             100.000000
# HashRate              100.000000
# IssContNtv            100.000000
# IssContPctAnn         100.000000
# IssContUSD            100.000000
# IssTotNtv             100.000000
# IssTotUSD             100.000000
# NVTAdj                100.000000
# NVTAdj90               97.681084
# PriceBTC              100.000000
# PriceUSD              100.000000
# ROI1yr                 90.489838
# ROI30d                 99.218343
# SplyCur               100.000000
# SplyExpFut10yrCMBI    100.000000
# SplyFF                100.000000
# TxCnt                 100.000000
# TxTfrCnt              100.000000
# TxTfrValAdjNtv        100.000000
# TxTfrValAdjUSD        100.000000
# TxTfrValMeanNtv       100.000000
# TxTfrValMeanUSD       100.000000
# TxTfrValMedNtv        100.000000
# TxTfrValMedUSD        100.000000
# TxTfrValNtv           100.000000
# TxTfrValUSD           100.000000
# VtyDayRet180d          95.310057
# VtyDayRet30d           99.218343
# VtyDayRet60d           98.436686
# dtype: float64

# %%
#replacing non-null values with zeros.
data = data.fillna(0)
data.head()
data_pct_non_null = data.count()/len(data)*100
data_pct_non_null
# Out:
# AdrActCnt             100.0
# BlkCnt                100.0
# BlkSizeByte           100.0
# BlkSizeMeanByte       100.0
# CapMVRVCur            100.0
# CapMrktCurUSD         100.0
# CapRealUSD            100.0
# DiffMean              100.0
# FeeMeanNtv            100.0
# FeeMeanUSD            100.0
# FeeMedNtv             100.0
# FeeMedUSD             100.0
# FeeTotNtv             100.0
# FeeTotUSD             100.0
# HashRate              100.0
# IssContNtv            100.0
# IssContPctAnn         100.0
# IssContUSD            100.0
# IssTotNtv             100.0
# IssTotUSD             100.0
# NVTAdj                100.0
# NVTAdj90              100.0
# PriceBTC              100.0
# PriceUSD              100.0
# ROI1yr                100.0
# ROI30d                100.0
# SplyCur               100.0
# SplyExpFut10yrCMBI    100.0
# SplyFF                100.0
# TxCnt                 100.0
# TxTfrCnt              100.0
# TxTfrValAdjNtv        100.0
# TxTfrValAdjUSD        100.0
# TxTfrValMeanNtv       100.0
# TxTfrValMeanUSD       100.0
# TxTfrValMedNtv        100.0
# TxTfrValMedUSD        100.0
# TxTfrValNtv           100.0
# TxTfrValUSD           100.0
# VtyDayRet180d         100.0
# VtyDayRet30d          100.0
# VtyDayRet60d          100.0
# dtype: float64

# %%
#Additional dataframes for monthly and annual data will be created to analyse in next stages
#if there are clearer paterns.
#agg_dict shows the agg fnction for each column in data.

agg_dict = {'AdrActCnt': 'mean', 'BlkCnt': 'sum', 'BlkSizeByte': 'sum', 'BlkSizeMeanByte': 'mean', 'CapMVRVCur': 'mean',
       'CapMrktCurUSD': 'mean', 'CapRealUSD': 'mean', 'DiffMean': 'mean', 'FeeMeanNtv': 'mean', 'FeeMeanUSD': 'mean',
       'FeeMedNtv': 'mean', 'FeeMedUSD': 'mean', 'FeeTotNtv': 'sum', 'FeeTotUSD': 'sum', 'HashRate': 'mean',
       'IssContNtv': 'sum', 'IssContPctAnn': 'mean', 'IssContUSD': 'sum', 'IssTotNtv': 'sum', 'IssTotUSD': 'sum',
       'NVTAdj': 'mean', 'NVTAdj90': 'mean', 'PriceBTC': 'mean', 'PriceUSD': 'mean', 'ROI1yr': 'mean', 'ROI30d': 'mean',
       'SplyCur': lambda x: x.iloc[-1], 'SplyExpFut10yrCMBI': lambda x: x.iloc[-1], 'SplyFF': lambda x: x.iloc[-1], 'TxCnt': 'sum',
       'TxTfrCnt': 'sum', 'TxTfrValAdjNtv': 'sum' , 'TxTfrValAdjUSD': 'sum', 'TxTfrValMeanNtv': 'mean',
       'TxTfrValMeanUSD': 'mean', 'TxTfrValMedNtv': 'mean', 'TxTfrValMedUSD': 'mean', 'TxTfrValNtv': 'sum',
       'TxTfrValUSD': 'sum', 'VtyDayRet180d': 'mean', 'VtyDayRet30d': 'mean', 'VtyDayRet60d': 'mean'}
    
#resample data by month.
monthly_data = data.resample('M').agg(agg_dict)
monthly_data.to_csv('../data/processed/monthly_data.csv')
monthly_data.tail()
# Out:
#                AdrActCnt  BlkCnt   BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# time
# 2020-09-30  9.813088e+05  4531.0  5.610316e+09     1.240624e+06    1.710163
# 2020-10-31  9.420100e+05  4201.0  5.250980e+09     1.253807e+06    1.867554
# 2020-11-30  1.025808e+06  4466.0  5.628701e+09     1.263287e+06    2.367564
# 2020-12-31  1.071403e+06  4514.0  5.810117e+09     1.288197e+06    2.698953
# 2021-01-31  1.173570e+06  2760.0  3.612441e+09     1.309327e+06    3.362885
#
#             CapMrktCurUSD    CapRealUSD      DiffMean  FeeMeanNtv  FeeMeanUSD  \
# time
# 2020-09-30   1.968752e+11  1.151173e+11  1.811011e+13    0.000258    2.742665
# 2020-10-31   2.202892e+11  1.178209e+11  1.962374e+13    0.000384    4.759958
# 2020-11-30   3.091679e+11  1.303093e+11  1.749313e+13    0.000378    6.010938
# 2020-12-31   4.085532e+11  1.505576e+11  1.886431e+13    0.000310    6.941537
# 2021-01-31   6.681303e+11  1.988497e+11  1.965005e+13    0.000328   11.874833
#
#             ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  \
# time        ...
# 2020-09-30  ...    7.768880e+10         0.642011      6833.657834
# 2020-10-31  ...    9.209141e+10         0.689157      8245.459202
# 2020-11-30  ...    1.357155e+11         0.686681     11364.799138
# 2020-12-31  ...    1.895307e+11         0.653798     14506.197349
# 2021-01-31  ...    1.883416e+11         0.667512     23967.771606
#
#             TxTfrValMedNtv  TxTfrValMedUSD   TxTfrValNtv   TxTfrValUSD  \
# time
# 2020-09-30        0.009986      106.267283  1.621817e+07  1.727771e+11
# 2020-10-31        0.009388      111.542235  1.708541e+07  2.038261e+11
# 2020-11-30        0.007688      127.259406  1.698539e+07  2.819199e+11
# 2020-12-31        0.006207      135.024926  1.758159e+07  3.911212e+11
# 2021-01-31        0.004601      164.806022  1.131418e+07  4.078146e+11
#
#             VtyDayRet180d  VtyDayRet30d  VtyDayRet60d
# time
# 2020-09-30       0.035837      0.027899      0.027670
# 2020-10-31       0.027740      0.018368      0.023847
# 2020-11-30       0.025746      0.028251      0.023978
# 2020-12-31       0.026899      0.035903      0.032412
# 2021-01-31       0.030708      0.039808      0.038250
#
# [5 rows x 42 columns]

# %%
#resample data by year.
annual_data = data.resample('A').agg(agg_dict)
annual_data.to_csv('../data/processed/annual_data.csv')
annual_data
# Out:
#                AdrActCnt   BlkCnt   BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# time
# 2010-12-31  8.335150e+02  31630.0  3.788206e+07     1.297562e+03    7.090611
# 2011-12-31  1.229501e+04  59627.0  8.018074e+08     1.420473e+04    2.479248
# 2012-12-31  3.014668e+04  54526.0  3.797173e+09     7.034127e+04    1.423834
# 2013-12-31  8.284341e+04  63433.0  9.385366e+09     1.500106e+05    2.685971
# 2014-12-31  1.814790e+05  58865.0  1.452069e+10     2.516785e+05    1.594508
# 2015-12-31  3.010761e+05  54321.0  2.604091e+10     4.801743e+05    0.936284
# 2016-12-31  5.153452e+05  54851.0  4.258150e+10     7.816624e+05    1.609995
# 2017-12-31  7.558321e+05  55928.0  5.292733e+10     9.492896e+05    2.705348
# 2018-12-31  6.657010e+05  54498.0  4.799031e+10     8.881502e+05    1.453296
# 2019-12-31  7.160835e+05  54232.0  5.803817e+10     1.074397e+06    1.436337
# 2020-12-31  8.958950e+05  53222.0  6.297726e+10     1.188946e+06    1.762147
# 2021-12-31  1.173570e+06   2760.0  3.612441e+09     1.309327e+06    3.362885
#
#             CapMrktCurUSD    CapRealUSD      DiffMean  FeeMeanNtv  FeeMeanUSD  \
# time
# 2010-12-31   6.331603e+05  1.541879e+05  3.649643e+03    0.000612    0.000060
# 2011-12-31   3.861201e+07  2.610272e+07  8.621567e+05    0.001543    0.010471
# 2012-12-31   7.993273e+07  5.353516e+07  2.121159e+06    0.000943    0.007473
# 2013-12-31   2.228718e+09  7.489202e+08  1.637818e+08    0.000788    0.103297
# 2014-12-31   6.757827e+09  4.324092e+09  1.834246e+10    0.000187    0.100648
# 2015-12-31   3.928211e+09  4.179608e+09  5.436260e+10    0.000178    0.048629
# 2016-12-31   8.926094e+09  5.458429e+09  2.046476e+11    0.000268    0.158407
# 2017-12-31   6.626436e+10  2.217930e+10  8.291204e+11    0.000956    4.874578
# 2018-12-31   1.283610e+11  8.781141e+10  4.970596e+12    0.000278    2.897676
# 2019-12-31   1.314117e+11  8.967253e+10  8.995568e+12    0.000159    1.242841
# 2020-12-31   2.049679e+11  1.131443e+11  1.659005e+13    0.000234    2.885219
# 2021-12-31   6.681303e+11  1.988497e+11  1.965005e+13    0.000328   11.874833
#
#             ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  \
# time        ...
# 2010-12-31  ...    1.105034e+06       195.392381        27.108394
# 2011-12-31  ...    4.673696e+08        69.041664       348.426814
# 2012-12-31  ...    9.105038e+08        48.716734       419.353287
# 2013-12-31  ...    2.197955e+10         8.829844      1518.834127
# 2014-12-31  ...    3.435196e+10         3.207021      1725.361838
# 2015-12-31  ...    3.241331e+10         3.897498      1127.893510
# 2016-12-31  ...    8.794020e+10         4.782689      2426.564665
# 2017-12-31  ...    6.713100e+11         2.599866     10133.203211
# 2018-12-31  ...    7.534700e+11         1.310201     10096.028805
# 2019-12-31  ...    6.730847e+11         0.978231      7063.936384
# 2020-12-31  ...    9.996456e+11         0.757312      8136.224322
# 2021-12-31  ...    1.883416e+11         0.667512     23967.771606
#
#             TxTfrValMedNtv  TxTfrValMedUSD   TxTfrValNtv   TxTfrValUSD  \
# time
# 2010-12-31       13.302784        1.826968  1.289854e+07  1.935703e+06
# 2011-12-31        1.150084        4.115153  2.926536e+08  2.509709e+09
# 2012-12-31        0.319891        1.926208  8.988208e+08  8.810182e+09
# 2013-12-31        0.048970        9.281768  3.869203e+08  8.136131e+10
# 2014-12-31        0.031913       16.619881  2.202999e+08  1.150737e+11
# 2015-12-31        0.024360        6.906548  4.914099e+08  1.491670e+11
# 2016-12-31        0.025398       14.308969  9.042906e+08  4.626165e+11
# 2017-12-31        0.021645       75.887161  6.370922e+08  2.763896e+12
# 2018-12-31        0.012467       98.985158  2.663874e+08  2.117775e+12
# 2019-12-31        0.010868       73.888608  2.565331e+08  1.887381e+12
# 2020-12-31        0.009623      101.175822  2.119789e+08  2.335824e+12
# 2021-12-31        0.004601      164.806022  1.131418e+07  4.078146e+11
#
#             VtyDayRet180d  VtyDayRet30d  VtyDayRet60d
# time
# 2010-12-31       0.000000      0.059727      0.050218
# 2011-12-31       0.088670      0.082654      0.087593
# 2012-12-31       0.051386      0.035219      0.039004
# 2013-12-31       0.063635      0.058025      0.058482
# 2014-12-31       0.051602      0.039100      0.043846
# 2015-12-31       0.035214      0.032386      0.033617
# 2016-12-31       0.029502      0.023457      0.025207
# 2017-12-31       0.039583      0.044320      0.043977
# 2018-12-31       0.046992      0.041816      0.043065
# 2019-12-31       0.038540      0.035544      0.037223
# 2020-12-31       0.039545      0.034791      0.036166
# 2021-12-31       0.030708      0.039808      0.038250
#
# [12 rows x 42 columns]

# %%
annual_prices = annual_data['PriceUSD']
annual_prices
# Out:
# time
# 2010-12-31        0.140855
# 2011-12-31        5.641328
# 2012-12-31        8.291235
# 2013-12-31      188.857898
# 2014-12-31      525.173537
# 2015-12-31      272.880117
# 2016-12-31      568.197748
# 2017-12-31     3994.489110
# 2018-12-31     7519.170891
# 2019-12-31     7365.207125
# 2020-12-31    11119.063627
# 2021-12-31    35928.152747
# Freq: A-DEC, Name: PriceUSD, dtype: float64

# %%
#The goal here is to create a column that accounts for the halving periods of bitcoin block subsidy.

#First we create the column 'block_height', which is the cumulative sum of blocks produced each day.
data['block_height'] = raw_data['BlkCnt'].cumsum(axis=0)
print(data['block_height'])

#We create the 'halving_period' column by dividing the 'block_height' by 210,000 
data['halving_period'] = data['block_height'].apply(lambda x: x // 210000)
data['halving_period']

#The 'halving_period' column will allow us to analize the data taking into account the halving periods.
# Out:
# time
# 2010-07-18     68956.0
# 2010-07-19     69130.0
# 2010-07-20     69311.0
# 2010-07-21     69518.0
# 2010-07-22     69694.0
#                 ...
# 2021-01-14    666097.0
# 2021-01-15    666252.0
# 2021-01-16    666399.0
# 2021-01-17    666532.0
# 2021-01-18    666677.0
# Name: block_height, Length: 3838, dtype: float64
# time
# 2010-07-18    0.0
# 2010-07-19    0.0
# 2010-07-20    0.0
# 2010-07-21    0.0
# 2010-07-22    0.0
#              ...
# 2021-01-14    3.0
# 2021-01-15    3.0
# 2021-01-16    3.0
# 2021-01-17    3.0
# 2021-01-18    3.0
# Name: halving_period, Length: 3838, dtype: float64

# %%
#saving data to csv file
data.to_csv('../data/processed/data.csv')
