# %%
#importing packages.
import pandas as pd
from collections import Counter

# %%
#DATA COLLECTION - fetching raw database in csv format from url.
url = 'https://raw.githubusercontent.com/coinmetrics-io/data/master/csv/btc.csv'
raw_data = pd.read_csv(url)
raw_data.tail()
# Out:
#             time  AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# 4373  2020-12-24   969168.0   126.0  159814962.0     1.268373e+06    2.773205
# 4374  2020-12-25  1021183.0   144.0  185748129.0     1.289918e+06    2.877421
# 4375  2020-12-26   957062.0   137.0  189574027.0     1.383752e+06    3.067328
# 4376  2020-12-27  1049825.0   148.0  193716651.0     1.308896e+06    3.033870
# 4377  2020-12-28  1154354.0   160.0  206766595.0     1.292291e+06    3.033361
#
#       CapMrktCurUSD    CapRealUSD      DiffMean  FeeMeanNtv  ...  \
# 4373   4.404891e+11  1.588376e+11  1.867017e+13    0.000393  ...
# 4374   4.583766e+11  1.593012e+11  1.867017e+13    0.000296  ...
# 4375   4.920104e+11  1.604036e+11  1.867017e+13    0.000257  ...
# 4376   4.911576e+11  1.618915e+11  1.866826e+13    0.000295  ...
# 4377   5.024921e+11  1.656552e+11  1.859959e+13    0.000327  ...
#
#       TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  \
# 4373    6.661231e+09         0.686637     16278.539978        0.005893
# 4374    4.052616e+09         0.466259     11502.229096        0.005015
# 4375    5.126191e+09         0.577703     15296.451766        0.005306
# 4376    6.391999e+09         0.657102     17367.771562        0.005215
# 4377    1.075143e+10         0.809730     21894.585318        0.005513
#
#       TxTfrValMedUSD    TxTfrValNtv   TxTfrValUSD  VtyDayRet180d  \
# 4373      139.716787  525460.013305  1.245741e+10       0.027387
# 4374      123.719683  367054.765216  9.054934e+09       0.027503
# 4375      140.493291  441635.237225  1.169365e+10       0.027929
# 4376      137.846432  531357.733666  1.404424e+10       0.027924
# 4377      149.061442  708320.652738  1.915253e+10       0.027950
#
#       VtyDayRet30d  VtyDayRet60d
# 4373      0.037981      0.033791
# 4374      0.038044      0.033995
# 4375      0.034650      0.034604
# 4376      0.034667      0.034255
# 4377      0.034447      0.034285
#
# [5 rows x 43 columns]

# %%
#Info from raw_data
#43 columns and 4329 rows
#All columns are floats, except the first column 'time' (object type), which is the date.
#Column PriceUSD, the price of bitcoin in USD, has 3768 entries.
#For modeling purposes we may have to drop the rows where PriceUSD is null.
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4378 entries, 0 to 4377
# Data columns (total 43 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   time                4378 non-null   object
#  1   AdrActCnt           4378 non-null   float64
#  2   BlkCnt              4378 non-null   float64
#  3   BlkSizeByte         4378 non-null   float64
#  4   BlkSizeMeanByte     4372 non-null   float64
#  5   CapMVRVCur          3817 non-null   float64
#  6   CapMrktCurUSD       3817 non-null   float64
#  7   CapRealUSD          4378 non-null   float64
#  8   DiffMean            4372 non-null   float64
#  9   FeeMeanNtv          4120 non-null   float64
#  10  FeeMeanUSD          3817 non-null   float64
#  11  FeeMedNtv           4120 non-null   float64
#  12  FeeMedUSD           3817 non-null   float64
#  13  FeeTotNtv           4378 non-null   float64
#  14  FeeTotUSD           3817 non-null   float64
#  15  HashRate            4372 non-null   float64
#  16  IssContNtv          4372 non-null   float64
#  17  IssContPctAnn       4372 non-null   float64
#  18  IssContUSD          3817 non-null   float64
#  19  IssTotNtv           4372 non-null   float64
#  20  IssTotUSD           3817 non-null   float64
#  21  NVTAdj              4118 non-null   float64
#  22  NVTAdj90            3728 non-null   float64
#  23  PriceBTC            4378 non-null   float64
#  24  PriceUSD            3817 non-null   float64
#  25  ROI1yr              3452 non-null   float64
#  26  ROI30d              3787 non-null   float64
#  27  SplyCur             4378 non-null   float64
#  28  SplyExpFut10yrCMBI  4372 non-null   float64
#  29  SplyFF              4378 non-null   float64
#  30  TxCnt               4378 non-null   float64
#  31  TxTfrCnt            4378 non-null   float64
#  32  TxTfrValAdjNtv      4378 non-null   float64
#  33  TxTfrValAdjUSD      3817 non-null   float64
#  34  TxTfrValMeanNtv     4120 non-null   float64
#  35  TxTfrValMeanUSD     3817 non-null   float64
#  36  TxTfrValMedNtv      4120 non-null   float64
#  37  TxTfrValMedUSD      3817 non-null   float64
#  38  TxTfrValNtv         4378 non-null   float64
#  39  TxTfrValUSD         3817 non-null   float64
#  40  VtyDayRet180d       3637 non-null   float64
#  41  VtyDayRet30d        3787 non-null   float64
#  42  VtyDayRet60d        3757 non-null   float64
# dtypes: float64(42), object(1)
# memory usage: 1.4+ MB

# %%
#The variable definitions for each column is in the 'metrics_info.csv' file.
metrics_info = pd.read_csv('../data/raw/metrics_info.csv').transpose()
#Here I also name the columns with the id row and "erase" the 'id' row.
metrics_info.columns = metrics_info.loc['id']
metrics_info = metrics_info.loc['name': 'description']
metrics_info
# Out:
# id                                                   AdrActCnt  \
# name                                  Addresses, active, count
# category                                             Addresses
# subcategory                                             Active
# type                                                       Sum
# unit                                                 Addresses
# interval                                                 1 day
# interval_rt                                            1 block
# description  The sum count of unique addresses that were ac...
#
# id                                                      BlkCnt  \
# name                                              Block, count
# category                                         Network Usage
# subcategory                                             Blocks
# type                                                       Sum
# unit                                                    Blocks
# interval                                                 1 day
# interval_rt                                                NaN
# description  The sum count of blocks created that interval ...
#
# id                                                 BlkSizeByte  \
# name                                        Block, size, bytes
# category                                         Network Usage
# subcategory                                             Blocks
# type                                                       Sum
# unit                                                     Bytes
# interval                                                 1 day
# interval_rt                                            1 block
# description  The sum of the size (in bytes) of all blocks c...
#
# id                                             BlkSizeMeanByte  \
# name                                  Block, size, mean, bytes
# category                                         Network Usage
# subcategory                                             Blocks
# type                                                      Mean
# unit                                                     Bytes
# interval                                                 1 day
# interval_rt                                                NaN
# description  The mean size (in bytes) of all blocks created...
#
# id                                                  CapMVRVCur  \
# name                      Capitalization, MVRV, current supply
# category                                                Market
# subcategory                              Market Capitalization
# type                                                     Ratio
# unit                                             Dimensionless
# interval                                                 1 day
# interval_rt                                                NaN
# description  The ratio of the sum USD value of the current ...
#
# id                                               CapMrktCurUSD  \
# name               Capitalization, market, current supply, USD
# category                                                Market
# subcategory                              Market Capitalization
# type                                                   Product
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                                NaN
# description  The sum USD value of the current supply. Also ...
#
# id                                                  CapRealUSD  \
# name                             Capitalization, realized, USD
# category                                                Market
# subcategory                              Market Capitalization
# type                                                   Product
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                                NaN
# description  The sum USD value based on the USD closing pri...
#
# id                                                    DiffMean  \
# name                                          Difficulty, mean
# category                                                Mining
# subcategory                                         Difficulty
# type                                                      Mean
# unit                                             Dimensionless
# interval                                                 1 day
# interval_rt                                            1 block
# description  The mean difficulty of finding a hash that mee...
#
# id                                                  FeeMeanNtv  \
# name                     Fees, transaction, mean, native units
# category                                      Fees and Revenue
# subcategory                                               Fees
# type                                                      Mean
# unit                                              Native units
# interval                                                 1 day
# interval_rt                                            1 block
# description  The mean fee per transaction in native units t...
#
# id                                                  FeeMeanUSD  ...  \
# name                              Fees, transaction, mean, USD  ...
# category                                      Fees and Revenue  ...
# subcategory                                               Fees  ...
# type                                                      Mean  ...
# unit                                                       USD  ...
# interval                                                 1 day  ...
# interval_rt                                            1 block  ...
# description  The USD value of the mean fee per transaction ...  ...
#
# id                                              TxTfrValAdjUSD  \
# name             Transactions, transfers, value, adjusted, USD
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                       Sum
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                                NaN
# description  The USD value of the sum of native units trans...
#
# id                                             TxTfrValMeanNtv  \
# name         Transactions, transfers, value, mean, native u...
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                      Mean
# unit                                              Native units
# interval                                                 1 day
# interval_rt                                            1 block
# description  The mean count of native units transferred per...
#
# id                                             TxTfrValMeanUSD  \
# name                 Transactions, transfers, value, mean, USD
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                      Mean
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                            1 block
# description  The sum USD value of native units transferred ...
#
# id                                              TxTfrValMedNtv  \
# name         Transactions, transfers, value, median, native...
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                    Median
# unit                                              Native units
# interval                                                 1 day
# interval_rt                                            1 block
# description  The median count of native units transferred p...
#
# id                                              TxTfrValMedUSD  \
# name               Transactions, transfers, value, median, USD
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                    Median
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                            1 block
# description  The median USD value transferred per transfer ...
#
# id                                                 TxTfrValNtv  \
# name              Transactions, transfers, value, native units
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                       Sum
# unit                                              Native units
# interval                                                 1 day
# interval_rt                                            1 block
# description  The sum of native units transferred (i.e., the...
#
# id                                                 TxTfrValUSD  \
# name                       Transactions, transfers, value, USD
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                       Sum
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                            1 block
# description  The sum USD value of all native units transfer...
#
# id                                               VtyDayRet180d  \
# name                           Volatility, daily returns, 180d
# category                                                Market
# subcategory                                         Volatility
# type                                                     Ratio
# unit                                             Dimensionless
# interval                                              180 days
# interval_rt                                                NaN
# description  The 180D volatility, measured as the standard ...
#
# id                                                VtyDayRet30d  \
# name                            Volatility, daily returns, 30d
# category                                                Market
# subcategory                                         Volatility
# type                                                     Ratio
# unit                                             Dimensionless
# interval                                               30 days
# interval_rt                                                NaN
# description  The 30D volatility, measured as the standard d...
#
# id                                                VtyDayRet60d
# name                            Volatility, daily returns, 60d
# category                                                Market
# subcategory                                         Volatility
# type                                                     Ratio
# unit                                             Dimensionless
# interval                                               60 days
# interval_rt                                                NaN
# description  The 60D volatility, measured as the standard d...
#
# [8 rows x 42 columns]

# %%
#null values of PriceUSD column
Counter(pd.isnull(raw_data['PriceUSD']))
# Out:
# Counter({True: 561, False: 3817})

# %%
#Sumamry statistics
raw_data.describe()
# Out:
#           AdrActCnt       BlkCnt   BlkSizeByte  BlkSizeMeanByte   CapMVRVCur  \
# count  4.378000e+03  4378.000000  4.378000e+03     4.372000e+03  3817.000000
# mean   3.461224e+05   151.536546  7.274946e+07     4.879744e+05     2.038610
# std    3.376402e+05    35.235144  6.661735e+07     4.515800e+05     3.005191
# min    0.000000e+00     0.000000  0.000000e+00     2.150000e+02     0.386829
# 25%    1.726400e+04   138.000000  3.340891e+06     2.228108e+04     1.245846
# 50%    2.295880e+05   152.000000  5.070548e+07     3.488701e+05     1.678980
# 75%    6.434968e+05   166.000000  1.362943e+08     9.361656e+05     2.259111
# max    1.290363e+06   692.000000  2.565337e+08     1.427240e+06   146.038332
#
#        CapMrktCurUSD    CapRealUSD      DiffMean   FeeMeanNtv   FeeMeanUSD  \
# count   3.817000e+03  4.378000e+03  4.372000e+03  4120.000000  3817.000000
# mean    5.251885e+10  2.722287e+10  2.634478e+12     0.000918     1.172701
# std     7.839813e+10  4.154587e+10  5.093044e+12     0.007737     3.756207
# min     1.776705e+05  0.000000e+00  1.000000e+00     0.000000     0.000000
# 25%     3.374944e+08  4.335254e+07  1.563028e+06     0.000140     0.031961
# 50%     6.953267e+09  4.179769e+09  4.064096e+10     0.000233     0.112841
# 75%     1.070790e+11  7.628860e+10  1.885939e+12     0.000676     0.790702
# max     5.024921e+11  1.656552e+11  1.999734e+13     0.220000    56.308124
#
#        ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  \
# count  ...    3.817000e+03      4120.000000      3817.000000    4.120000e+03
# mean   ...    8.507663e+08        94.903200      4099.427238    5.468306e+01
# std    ...    1.343815e+09       677.274504      5509.262079    6.400500e+02
# min    ...    4.647065e+02         0.010000         0.762873    1.000000e-08
# 25%    ...    1.276615e+07         1.474486       528.926276    1.154420e-02
# 50%    ...    1.525393e+08         3.487641      1728.664955    2.813089e-02
# 75%    ...    1.438041e+09        21.486792      6412.829288    1.000000e-01
# max    ...    1.082210e+10     22175.000000     51124.770624    2.217500e+04
#
#        TxTfrValMedUSD   TxTfrValNtv   TxTfrValUSD  VtyDayRet180d  \
# count    3.817000e+03  4.378000e+03  3.817000e+03    3637.000000
# mean     3.853519e+01  1.046945e+06  2.584700e+09       0.048650
# std      5.253372e+01  1.915094e+06  4.447661e+09       0.021278
# min      8.203471e-08  0.000000e+00  5.874592e+02       0.020298
# 25%      3.476787e+00  3.590702e+05  5.352672e+07       0.032490
# 50%      1.499590e+01  6.760669e+05  5.784457e+08       0.042529
# 75%      6.746700e+01  1.271507e+06  3.944849e+09       0.058678
# max      5.348536e+02  6.725965e+07  4.877049e+10       0.109532
#
#        VtyDayRet30d  VtyDayRet60d
# count   3787.000000   3757.000000
# mean       0.043818      0.045773
# std        0.029602      0.026748
# min        0.007481      0.010406
# 25%        0.024747      0.027623
# 50%        0.035355      0.038070
# 75%        0.052613      0.056957
# max        0.191722      0.143269
#
# [8 rows x 42 columns]

# %%
#setting date column as index and droping it from columns
raw_data.index = pd.to_datetime(raw_data['time'])
raw_data = raw_data.drop('time', axis='columns')
raw_data.tail()
# Out:
#             AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# time
# 2020-12-24   969168.0   126.0  159814962.0     1.268373e+06    2.773205
# 2020-12-25  1021183.0   144.0  185748129.0     1.289918e+06    2.877421
# 2020-12-26   957062.0   137.0  189574027.0     1.383752e+06    3.067328
# 2020-12-27  1049825.0   148.0  193716651.0     1.308896e+06    3.033870
# 2020-12-28  1154354.0   160.0  206766595.0     1.292291e+06    3.033361
#
#             CapMrktCurUSD    CapRealUSD      DiffMean  FeeMeanNtv  FeeMeanUSD  \
# time
# 2020-12-24   4.404891e+11  1.588376e+11  1.867017e+13    0.000393    9.324175
# 2020-12-25   4.583766e+11  1.593012e+11  1.867017e+13    0.000296    7.306476
# 2020-12-26   4.920104e+11  1.604036e+11  1.867017e+13    0.000257    6.801159
# 2020-12-27   4.911576e+11  1.618915e+11  1.866826e+13    0.000295    7.792538
# 2020-12-28   5.024921e+11  1.656552e+11  1.859959e+13    0.000327    8.834168
#
#             ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  \
# time        ...
# 2020-12-24  ...    6.661231e+09         0.686637     16278.539978
# 2020-12-25  ...    4.052616e+09         0.466259     11502.229096
# 2020-12-26  ...    5.126191e+09         0.577703     15296.451766
# 2020-12-27  ...    6.391999e+09         0.657102     17367.771562
# 2020-12-28  ...    1.075143e+10         0.809730     21894.585318
#
#             TxTfrValMedNtv  TxTfrValMedUSD    TxTfrValNtv   TxTfrValUSD  \
# time
# 2020-12-24        0.005893      139.716787  525460.013305  1.245741e+10
# 2020-12-25        0.005015      123.719683  367054.765216  9.054934e+09
# 2020-12-26        0.005306      140.493291  441635.237225  1.169365e+10
# 2020-12-27        0.005215      137.846432  531357.733666  1.404424e+10
# 2020-12-28        0.005513      149.061442  708320.652738  1.915253e+10
#
#             VtyDayRet180d  VtyDayRet30d  VtyDayRet60d
# time
# 2020-12-24       0.027387      0.037981      0.033791
# 2020-12-25       0.027503      0.038044      0.033995
# 2020-12-26       0.027929      0.034650      0.034604
# 2020-12-27       0.027924      0.034667      0.034255
# 2020-12-28       0.027950      0.034447      0.034285
#
# [5 rows x 42 columns]

# %%
#drop rows in 'PriceUSD' with NaN values
data = raw_data.dropna(subset=['PriceUSD'])
data.head()
# Out:
#             AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# time
# 2010-07-18      860.0   172.0     136889.0       795.866279  146.038332
# 2010-07-19      929.0   174.0     139254.0       800.310345   62.565130
# 2010-07-20      936.0   181.0     197425.0      1090.745856   45.106630
# 2010-07-21      784.0   207.0     124991.0       603.821256   38.357560
# 2010-07-22      594.0   176.0     100750.0       572.443182   25.132348
#
#             CapMrktCurUSD   CapRealUSD    DiffMean  FeeMeanNtv  FeeMeanUSD  \
# time
# 2010-07-18  295959.152000  2026.585401  181.543289    0.003185    0.000273
# 2010-07-19  279285.200000  4463.911468  181.543289    0.000150    0.000012
# 2010-07-20  259000.404990  5741.958660  181.543289    0.000000    0.000000
# 2010-07-21  275266.471297  7176.328942  181.543289    0.000000    0.000000
# 2010-07-22  203749.573975  8107.064743  181.543289    0.000000    0.000000
#
#             ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  \
# time        ...
# 2010-07-18  ...     1474.778412        48.783737         4.187596
# 2010-07-19  ...     3251.693384        86.951152         7.025653
# 2010-07-20  ...     1200.497201        42.528835         3.178423
# 2010-07-21  ...     1649.915979        71.822334         5.687816
# 2010-07-22  ...     1932.368865       112.714622         6.590397
#
#             TxTfrValMedNtv  TxTfrValMedUSD  TxTfrValNtv  TxTfrValUSD  \
# time
# 2010-07-18           1.850        0.158804     19318.36  1658.288022
# 2010-07-19           2.625        0.212100     44518.99  3597.134392
# 2010-07-20           1.375        0.102762     31386.28  2345.676511
# 2010-07-21          18.500        1.465068     27077.02  2144.306726
# 2010-07-22           1.010        0.059054     38773.83  2267.096549
#
#             VtyDayRet180d  VtyDayRet30d  VtyDayRet60d
# time
# 2010-07-18            NaN           NaN           NaN
# 2010-07-19            NaN           NaN           NaN
# 2010-07-20            NaN           NaN           NaN
# 2010-07-21            NaN           NaN           NaN
# 2010-07-22            NaN           NaN           NaN
#
# [5 rows x 42 columns]

# %%
data.describe()
# Out:
#           AdrActCnt       BlkCnt   BlkSizeByte  BlkSizeMeanByte   CapMVRVCur  \
# count  3.817000e+03  3817.000000  3.817000e+03     3.817000e+03  3817.000000
# mean   3.969645e+05   155.788053  8.343590e+07     5.588867e+05     2.038610
# std    3.325397e+05    23.621633  6.479855e+07     4.404096e+05     3.005191
# min    4.080000e+02    80.000000  7.103500e+04     4.164167e+02     0.386829
# 25%    5.572500e+04   141.000000  2.062202e+07     1.239423e+05     1.245846
# 50%    3.333620e+05   153.000000  8.273267e+07     5.429596e+05     1.678980
# 75%    6.811610e+05   166.000000  1.425111e+08     9.683225e+05     2.259111
# max    1.290363e+06   307.000000  2.565337e+08     1.427240e+06   146.038332
#
#        CapMrktCurUSD    CapRealUSD      DiffMean   FeeMeanNtv   FeeMeanUSD  \
# count   3.817000e+03  3.817000e+03  3.817000e+03  3817.000000  3817.000000
# mean    5.251885e+10  3.122392e+10  3.017537e+12     0.000556     1.172701
# std     7.839813e+10  4.306797e+10  5.343734e+12     0.001295     3.756207
# min     1.776705e+05  2.026585e+03  1.815433e+02     0.000000     0.000000
# 25%     3.374944e+08  1.196540e+08  3.651012e+06     0.000153     0.031961
# 50%     6.953267e+09  4.579008e+09  6.081322e+10     0.000262     0.112841
# 75%     1.070790e+11  8.005362e+10  4.143878e+12     0.000704     0.790702
# max     5.024921e+11  1.656552e+11  1.999734e+13     0.043644    56.308124
#
#        ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  \
# count  ...    3.817000e+03      3817.000000      3817.000000    3.817000e+03
# mean   ...    8.507663e+08        22.343935      4099.427238    7.403875e-01
# std    ...    1.343815e+09        71.687282      5509.262079    4.982883e+00
# min    ...    4.647065e+02         0.400728         0.762873    1.000000e-08
# 25%    ...    1.276615e+07         1.356260       528.926276    1.108504e-02
# 50%    ...    1.525393e+08         3.160393      1728.664955    2.500000e-02
# 75%    ...    1.438041e+09        12.321292      6412.829288    5.702909e-02
# max    ...    1.082210e+10      1412.355198     51124.770624    1.000000e+02
#
#        TxTfrValMedUSD   TxTfrValNtv   TxTfrValUSD  VtyDayRet180d  \
# count    3.817000e+03  3.817000e+03  3.817000e+03    3637.000000
# mean     3.853519e+01  1.199166e+06  2.584700e+09       0.048650
# std      5.253372e+01  2.006012e+06  4.447661e+09       0.021278
# min      8.203471e-08  9.179050e+03  5.874592e+02       0.020298
# 25%      3.476787e+00  5.121545e+05  5.352672e+07       0.032490
# 50%      1.499590e+01  7.735419e+05  5.784457e+08       0.042529
# 75%      6.746700e+01  1.391925e+06  3.944849e+09       0.058678
# max      5.348536e+02  6.725965e+07  4.877049e+10       0.109532
#
#        VtyDayRet30d  VtyDayRet60d
# count   3787.000000   3757.000000
# mean       0.043818      0.045773
# std        0.029602      0.026748
# min        0.007481      0.010406
# 25%        0.024747      0.027623
# 50%        0.035355      0.038070
# 75%        0.052613      0.056957
# max        0.191722      0.143269
#
# [8 rows x 42 columns]

# %%
#Most variables have now 100% non-null values.
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 3817 entries, 2010-07-18 to 2020-12-28
# Data columns (total 42 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   AdrActCnt           3817 non-null   float64
#  1   BlkCnt              3817 non-null   float64
#  2   BlkSizeByte         3817 non-null   float64
#  3   BlkSizeMeanByte     3817 non-null   float64
#  4   CapMVRVCur          3817 non-null   float64
#  5   CapMrktCurUSD       3817 non-null   float64
#  6   CapRealUSD          3817 non-null   float64
#  7   DiffMean            3817 non-null   float64
#  8   FeeMeanNtv          3817 non-null   float64
#  9   FeeMeanUSD          3817 non-null   float64
#  10  FeeMedNtv           3817 non-null   float64
#  11  FeeMedUSD           3817 non-null   float64
#  12  FeeTotNtv           3817 non-null   float64
#  13  FeeTotUSD           3817 non-null   float64
#  14  HashRate            3817 non-null   float64
#  15  IssContNtv          3817 non-null   float64
#  16  IssContPctAnn       3817 non-null   float64
#  17  IssContUSD          3817 non-null   float64
#  18  IssTotNtv           3817 non-null   float64
#  19  IssTotUSD           3817 non-null   float64
#  20  NVTAdj              3817 non-null   float64
#  21  NVTAdj90            3728 non-null   float64
#  22  PriceBTC            3817 non-null   float64
#  23  PriceUSD            3817 non-null   float64
#  24  ROI1yr              3452 non-null   float64
#  25  ROI30d              3787 non-null   float64
#  26  SplyCur             3817 non-null   float64
#  27  SplyExpFut10yrCMBI  3817 non-null   float64
#  28  SplyFF              3817 non-null   float64
#  29  TxCnt               3817 non-null   float64
#  30  TxTfrCnt            3817 non-null   float64
#  31  TxTfrValAdjNtv      3817 non-null   float64
#  32  TxTfrValAdjUSD      3817 non-null   float64
#  33  TxTfrValMeanNtv     3817 non-null   float64
#  34  TxTfrValMeanUSD     3817 non-null   float64
#  35  TxTfrValMedNtv      3817 non-null   float64
#  36  TxTfrValMedUSD      3817 non-null   float64
#  37  TxTfrValNtv         3817 non-null   float64
#  38  TxTfrValUSD         3817 non-null   float64
#  39  VtyDayRet180d       3637 non-null   float64
#  40  VtyDayRet30d        3787 non-null   float64
#  41  VtyDayRet60d        3757 non-null   float64
# dtypes: float64(42)
# memory usage: 1.3 MB

# %%
#Most columns have now 100% non-null values.
#Columns with less than 100% non-null values are data whose calculation depends on trailing moving averages
#of 30-365 days. These values will be set to zero.
data_pct_non_null = data.count()/len(data)*100
data_pct_non_null
# Out:
# AdrActCnt             100.000000
# BlkCnt                100.000000
# BlkSizeByte           100.000000
# BlkSizeMeanByte       100.000000
# CapMVRVCur            100.000000
# CapMrktCurUSD         100.000000
# CapRealUSD            100.000000
# DiffMean              100.000000
# FeeMeanNtv            100.000000
# FeeMeanUSD            100.000000
# FeeMedNtv             100.000000
# FeeMedUSD             100.000000
# FeeTotNtv             100.000000
# FeeTotUSD             100.000000
# HashRate              100.000000
# IssContNtv            100.000000
# IssContPctAnn         100.000000
# IssContUSD            100.000000
# IssTotNtv             100.000000
# IssTotUSD             100.000000
# NVTAdj                100.000000
# NVTAdj90               97.668326
# PriceBTC              100.000000
# PriceUSD              100.000000
# ROI1yr                 90.437516
# ROI30d                 99.214042
# SplyCur               100.000000
# SplyExpFut10yrCMBI    100.000000
# SplyFF                100.000000
# TxCnt                 100.000000
# TxTfrCnt              100.000000
# TxTfrValAdjNtv        100.000000
# TxTfrValAdjUSD        100.000000
# TxTfrValMeanNtv       100.000000
# TxTfrValMeanUSD       100.000000
# TxTfrValMedNtv        100.000000
# TxTfrValMedUSD        100.000000
# TxTfrValNtv           100.000000
# TxTfrValUSD           100.000000
# VtyDayRet180d          95.284255
# VtyDayRet30d           99.214042
# VtyDayRet60d           98.428085
# dtype: float64

# %%
#replacing non-null values with zeros.
data = data.fillna(0)
data.head()
data_pct_non_null = data.count()/len(data)*100
data_pct_non_null
# Out:
# AdrActCnt             100.0
# BlkCnt                100.0
# BlkSizeByte           100.0
# BlkSizeMeanByte       100.0
# CapMVRVCur            100.0
# CapMrktCurUSD         100.0
# CapRealUSD            100.0
# DiffMean              100.0
# FeeMeanNtv            100.0
# FeeMeanUSD            100.0
# FeeMedNtv             100.0
# FeeMedUSD             100.0
# FeeTotNtv             100.0
# FeeTotUSD             100.0
# HashRate              100.0
# IssContNtv            100.0
# IssContPctAnn         100.0
# IssContUSD            100.0
# IssTotNtv             100.0
# IssTotUSD             100.0
# NVTAdj                100.0
# NVTAdj90              100.0
# PriceBTC              100.0
# PriceUSD              100.0
# ROI1yr                100.0
# ROI30d                100.0
# SplyCur               100.0
# SplyExpFut10yrCMBI    100.0
# SplyFF                100.0
# TxCnt                 100.0
# TxTfrCnt              100.0
# TxTfrValAdjNtv        100.0
# TxTfrValAdjUSD        100.0
# TxTfrValMeanNtv       100.0
# TxTfrValMeanUSD       100.0
# TxTfrValMedNtv        100.0
# TxTfrValMedUSD        100.0
# TxTfrValNtv           100.0
# TxTfrValUSD           100.0
# VtyDayRet180d         100.0
# VtyDayRet30d          100.0
# VtyDayRet60d          100.0
# dtype: float64

# %%
#Additional dataframes for monthly and annual data will be created to analyse in next stages
#if there are clearer paterns.
#agg_dict shows the agg fnction for each column in data.

agg_dict = {'AdrActCnt': 'mean', 'BlkCnt': 'sum', 'BlkSizeByte': 'sum', 'BlkSizeMeanByte': 'mean', 'CapMVRVCur': 'mean',
       'CapMrktCurUSD': 'mean', 'CapRealUSD': 'mean', 'DiffMean': 'mean', 'FeeMeanNtv': 'mean', 'FeeMeanUSD': 'mean',
       'FeeMedNtv': 'mean', 'FeeMedUSD': 'mean', 'FeeTotNtv': 'sum', 'FeeTotUSD': 'sum', 'HashRate': 'mean',
       'IssContNtv': 'sum', 'IssContPctAnn': 'mean', 'IssContUSD': 'sum', 'IssTotNtv': 'sum', 'IssTotUSD': 'sum',
       'NVTAdj': 'mean', 'NVTAdj90': 'mean', 'PriceBTC': 'mean', 'PriceUSD': 'mean', 'ROI1yr': 'mean', 'ROI30d': 'mean',
       'SplyCur': lambda x: x.iloc[-1], 'SplyExpFut10yrCMBI': lambda x: x.iloc[-1], 'SplyFF': lambda x: x.iloc[-1], 'TxCnt': 'sum',
       'TxTfrCnt': 'sum', 'TxTfrValAdjNtv': 'sum' , 'TxTfrValAdjUSD': 'sum', 'TxTfrValMeanNtv': 'mean',
       'TxTfrValMeanUSD': 'mean', 'TxTfrValMedNtv': 'mean', 'TxTfrValMedUSD': 'mean', 'TxTfrValNtv': 'sum',
       'TxTfrValUSD': 'sum', 'VtyDayRet180d': 'mean', 'VtyDayRet30d': 'mean', 'VtyDayRet60d': 'mean'}
    
#resample data by month.
monthly_data = data.resample('M').agg(agg_dict)
monthly_data.to_csv('../data/processed/monthly_data.csv')
monthly_data.tail()
# Out:
#                AdrActCnt  BlkCnt   BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# time
# 2020-08-31  9.836875e+05  4521.0  5.763779e+09     1.275403e+06    1.906278
# 2020-09-30  9.813088e+05  4531.0  5.610316e+09     1.240624e+06    1.710163
# 2020-10-31  9.420100e+05  4201.0  5.250980e+09     1.253807e+06    1.867554
# 2020-11-30  1.025808e+06  4466.0  5.628701e+09     1.263287e+06    2.367564
# 2020-12-31  1.058998e+06  4024.0  5.186565e+09     1.289836e+06    2.656113
#
#             CapMrktCurUSD    CapRealUSD      DiffMean  FeeMeanNtv  FeeMeanUSD  \
# time
# 2020-08-31   2.150555e+11  1.128243e+11  1.706749e+13    0.000341    3.971937
# 2020-09-30   1.968752e+11  1.151173e+11  1.811011e+13    0.000258    2.742665
# 2020-10-31   2.202892e+11  1.178209e+11  1.962374e+13    0.000384    4.759958
# 2020-11-30   3.091679e+11  1.303093e+11  1.749313e+13    0.000378    6.010938
# 2020-12-31   3.958403e+11  1.484631e+11  1.889268e+13    0.000310    6.719817
#
#             ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  \
# time        ...
# 2020-08-31  ...    8.099134e+10         0.663137      7731.114218
# 2020-09-30  ...    7.768880e+10         0.642011      6833.657834
# 2020-10-31  ...    9.209141e+10         0.689157      8245.459202
# 2020-11-30  ...    1.357155e+11         0.686681     11364.799138
# 2020-12-31  ...    1.613313e+11         0.646348     13864.992874
#
#             TxTfrValMedNtv  TxTfrValMedUSD   TxTfrValNtv   TxTfrValUSD  \
# time
# 2020-08-31        0.009346      108.847766  1.712498e+07  1.995972e+11
# 2020-09-30        0.009986      106.267283  1.621817e+07  1.727771e+11
# 2020-10-31        0.009388      111.542235  1.708541e+07  2.038261e+11
# 2020-11-30        0.007688      127.259406  1.698539e+07  2.819199e+11
# 2020-12-31        0.006288      132.939826  1.551373e+07  3.325061e+11
#
#             VtyDayRet180d  VtyDayRet30d  VtyDayRet60d
# time
# 2020-08-31       0.050518      0.026793      0.022812
# 2020-09-30       0.035837      0.027899      0.027670
# 2020-10-31       0.027740      0.018368      0.023847
# 2020-11-30       0.025746      0.028251      0.023978
# 2020-12-31       0.026774      0.036206      0.032177
#
# [5 rows x 42 columns]

# %%
#resample data by year.
annual_data = data.resample('A').agg(agg_dict)
annual_data.to_csv('../data/processed/annual_data.csv')
annual_data
# Out:
#                 AdrActCnt   BlkCnt   BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# time
# 2010-12-31     833.514970  31630.0  3.788206e+07     1.297562e+03    7.090611
# 2011-12-31   12295.013699  59627.0  8.018074e+08     1.420473e+04    2.479248
# 2012-12-31   30146.677596  54526.0  3.797173e+09     7.034127e+04    1.423834
# 2013-12-31   82843.408219  63433.0  9.385366e+09     1.500106e+05    2.685971
# 2014-12-31  181478.969863  58865.0  1.452069e+10     2.516785e+05    1.594508
# 2015-12-31  301076.126027  54321.0  2.604091e+10     4.801743e+05    0.936284
# 2016-12-31  515345.180328  54851.0  4.258150e+10     7.816624e+05    1.609995
# 2017-12-31  755832.079452  55928.0  5.292733e+10     9.492896e+05    2.705348
# 2018-12-31  665700.956164  54498.0  4.799031e+10     8.881502e+05    1.453296
# 2019-12-31  716083.471233  54232.0  5.803817e+10     1.074397e+06    1.436337
# 2020-12-31  893487.677686  52732.0  6.235371e+10     1.188252e+06    1.751100
#
#             CapMrktCurUSD    CapRealUSD      DiffMean  FeeMeanNtv  FeeMeanUSD  \
# time
# 2010-12-31   6.331603e+05  1.541879e+05  3.649643e+03    0.000612    0.000060
# 2011-12-31   3.861201e+07  2.610272e+07  8.621567e+05    0.001543    0.010471
# 2012-12-31   7.993273e+07  5.353516e+07  2.121159e+06    0.000943    0.007473
# 2013-12-31   2.228718e+09  7.489202e+08  1.637818e+08    0.000788    0.103297
# 2014-12-31   6.757827e+09  4.324092e+09  1.834246e+10    0.000187    0.100648
# 2015-12-31   3.928211e+09  4.179608e+09  5.436260e+10    0.000178    0.048629
# 2016-12-31   8.926094e+09  5.458429e+09  2.046476e+11    0.000268    0.158407
# 2017-12-31   6.626436e+10  2.217930e+10  8.291204e+11    0.000956    4.874578
# 2018-12-31   1.283610e+11  8.781141e+10  4.970596e+12    0.000278    2.897676
# 2019-12-31   1.314117e+11  8.967253e+10  8.995568e+12    0.000159    1.242841
# 2020-12-31   2.023047e+11  1.126735e+11  1.657345e+13    0.000233    2.834593
#
#             ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  \
# time        ...
# 2010-12-31  ...    1.105034e+06       195.392381        27.108394
# 2011-12-31  ...    4.673696e+08        69.041664       348.426814
# 2012-12-31  ...    9.105038e+08        48.716734       419.353287
# 2013-12-31  ...    2.197955e+10         8.829844      1518.834127
# 2014-12-31  ...    3.435196e+10         3.207021      1725.361838
# 2015-12-31  ...    3.241331e+10         3.897498      1127.893510
# 2016-12-31  ...    8.794020e+10         4.782689      2426.564665
# 2017-12-31  ...    6.713100e+11         2.599866     10133.203211
# 2018-12-31  ...    7.534700e+11         1.310201     10096.028805
# 2019-12-31  ...    6.730847e+11         0.978231      7063.936384
# 2020-12-31  ...    9.714462e+11         0.757593      8034.120618
#
#             TxTfrValMedNtv  TxTfrValMedUSD   TxTfrValNtv   TxTfrValUSD  \
# time
# 2010-12-31       13.302784        1.826968  1.289854e+07  1.935703e+06
# 2011-12-31        1.150084        4.115153  2.926536e+08  2.509709e+09
# 2012-12-31        0.319891        1.926208  8.988208e+08  8.810182e+09
# 2013-12-31        0.048970        9.281768  3.869203e+08  8.136131e+10
# 2014-12-31        0.031913       16.619881  2.202999e+08  1.150737e+11
# 2015-12-31        0.024360        6.906548  4.914099e+08  1.491670e+11
# 2016-12-31        0.025398       14.308969  9.042906e+08  4.626165e+11
# 2017-12-31        0.021645       75.887161  6.370922e+08  2.763896e+12
# 2018-12-31        0.012467       98.985158  2.663874e+08  2.117775e+12
# 2019-12-31        0.010868       73.888608  2.565331e+08  1.887381e+12
# 2020-12-31        0.009658      100.735243  2.099110e+08  2.277209e+12
#
#             VtyDayRet180d  VtyDayRet30d  VtyDayRet60d
# time
# 2010-12-31       0.000000      0.059727      0.050218
# 2011-12-31       0.088670      0.082654      0.087593
# 2012-12-31       0.051386      0.035219      0.039004
# 2013-12-31       0.063635      0.058025      0.058482
# 2014-12-31       0.051602      0.039100      0.043846
# 2015-12-31       0.035214      0.032386      0.033617
# 2016-12-31       0.029502      0.023457      0.025207
# 2017-12-31       0.039583      0.044320      0.043977
# 2018-12-31       0.046992      0.041816      0.043065
# 2019-12-31       0.038540      0.035544      0.037223
# 2020-12-31       0.039640      0.034805      0.036178
#
# [11 rows x 42 columns]

# %%
annual_prices = annual_data['PriceUSD']
annual_prices
# Out:
# time
# 2010-12-31        0.140855
# 2011-12-31        5.641328
# 2012-12-31        8.291235
# 2013-12-31      188.857898
# 2014-12-31      525.173537
# 2015-12-31      272.880117
# 2016-12-31      568.197748
# 2017-12-31     3994.489110
# 2018-12-31     7519.170891
# 2019-12-31     7365.207125
# 2020-12-31    10976.525617
# Freq: A-DEC, Name: PriceUSD, dtype: float64

# %%
#The goal here is to create a column that accounts for the halving periods of bitcoin block subsidy.

#First we create the column 'block_height', which is the cumulative sum of blocks produced each day.
data['block_height'] = raw_data['BlkCnt'].cumsum(axis=0)
print(data['block_height'])

#We create the 'halving_period' column by dividing the 'block_height' by 210,000 
data['halving_period'] = data['block_height'].apply(lambda x: x // 210000)
data['halving_period']

#The 'halving_period' column will allow us to analize the data taking into account the halving periods.
# Out:
# time
# 2010-07-18     68956.0
# 2010-07-19     69130.0
# 2010-07-20     69311.0
# 2010-07-21     69518.0
# 2010-07-22     69694.0
#                 ...
# 2020-12-24    662838.0
# 2020-12-25    662982.0
# 2020-12-26    663119.0
# 2020-12-27    663267.0
# 2020-12-28    663427.0
# Name: block_height, Length: 3817, dtype: float64
# time
# 2010-07-18    0.0
# 2010-07-19    0.0
# 2010-07-20    0.0
# 2010-07-21    0.0
# 2010-07-22    0.0
#              ...
# 2020-12-24    3.0
# 2020-12-25    3.0
# 2020-12-26    3.0
# 2020-12-27    3.0
# 2020-12-28    3.0
# Name: halving_period, Length: 3817, dtype: float64

# %%
#saving data to csv file
data.to_csv('../data/processed/data.csv')
