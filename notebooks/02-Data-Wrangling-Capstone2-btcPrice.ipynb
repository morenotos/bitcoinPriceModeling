# %%
#importing packages.
import pandas as pd
from collections import Counter

# %%
#DATA COLLECTION - fetching raw database in csv format from url.
url = 'https://raw.githubusercontent.com/coinmetrics-io/data/master/csv/btc.csv'
raw_data = pd.read_csv(url)
raw_data.tail()
# Out:
#             time  AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# 4324  2020-11-05  1071518.0   147.0  188078794.0     1.279448e+06    2.307493
# 4325  2020-11-06  1080743.0   153.0  194685185.0     1.272452e+06    2.299192
# 4326  2020-11-07  1055012.0   146.0  198604086.0     1.360302e+06    2.187115
# 4327  2020-11-08   920529.0   138.0  189145770.0     1.370622e+06    2.269764
# 4328  2020-11-09  1188873.0   185.0  252934375.0     1.367213e+06    2.237517
#
#       CapMrktCurUSD    CapRealUSD      DiffMean  FeeMeanNtv  ...  \
# 4324   2.892633e+11  1.253583e+11  1.678778e+13    0.000831  ...
# 4325   2.895100e+11  1.259182e+11  1.678778e+13    0.000684  ...
# 4326   2.755732e+11  1.259985e+11  1.678778e+13    0.000500  ...
# 4327   2.873323e+11  1.265912e+11  1.678778e+13    0.000384  ...
# 4328   2.840099e+11  1.269308e+11  1.678778e+13    0.000440  ...
#
#       TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  \
# 4324    6.896637e+09         0.947055     14780.185040        0.010560
# 4325    5.377085e+09         0.798253     12467.889939        0.008849
# 4326    3.113639e+09         0.600304      8924.329906        0.006843
# 4327    2.807229e+09         0.637306      9878.241843        0.006680
# 4328    4.587933e+09         0.713117     10924.823338        0.008200
#
#       TxTfrValMedUSD    TxTfrValNtv   TxTfrValUSD  VtyDayRet180d  \
# 4324      164.807879  835637.914064  1.304136e+10       0.026765
# 4325      138.219785  706950.322346  1.104184e+10       0.025758
# 4326      101.735828  444455.314929  6.607431e+09       0.026023
# 4327      103.540005  420998.539315  6.525478e+09       0.026128
# 4328      125.622524  603186.409034  9.240707e+09       0.025851
#
#       VtyDayRet30d  VtyDayRet60d
# 4324      0.024748      0.022112
# 4325      0.024822      0.022120
# 4326      0.027211      0.022916
# 4327      0.027797      0.023359
# 4328      0.028047      0.023476
#
# [5 rows x 43 columns]

# %%
#Info from raw_data
#43 columns and 4329 rows
#All columns are floats, except the first column 'time' (object type), which is the date.
#Column PriceUSD, the price of bitcoin in USD, has 3768 entries.
#For modeling purposes we may have to drop the rows where PriceUSD is null.
raw_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4329 entries, 0 to 4328
# Data columns (total 43 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   time                4329 non-null   object
#  1   AdrActCnt           4329 non-null   float64
#  2   BlkCnt              4329 non-null   float64
#  3   BlkSizeByte         4329 non-null   float64
#  4   BlkSizeMeanByte     4323 non-null   float64
#  5   CapMVRVCur          3768 non-null   float64
#  6   CapMrktCurUSD       3768 non-null   float64
#  7   CapRealUSD          4329 non-null   float64
#  8   DiffMean            4323 non-null   float64
#  9   FeeMeanNtv          4071 non-null   float64
#  10  FeeMeanUSD          3768 non-null   float64
#  11  FeeMedNtv           4071 non-null   float64
#  12  FeeMedUSD           3768 non-null   float64
#  13  FeeTotNtv           4329 non-null   float64
#  14  FeeTotUSD           3768 non-null   float64
#  15  HashRate            4323 non-null   float64
#  16  IssContNtv          4323 non-null   float64
#  17  IssContPctAnn       4323 non-null   float64
#  18  IssContUSD          3768 non-null   float64
#  19  IssTotNtv           4323 non-null   float64
#  20  IssTotUSD           3768 non-null   float64
#  21  NVTAdj              4069 non-null   float64
#  22  NVTAdj90            3679 non-null   float64
#  23  PriceBTC            4329 non-null   float64
#  24  PriceUSD            3768 non-null   float64
#  25  ROI1yr              3403 non-null   float64
#  26  ROI30d              3738 non-null   float64
#  27  SplyCur             4329 non-null   float64
#  28  SplyExpFut10yrCMBI  4323 non-null   float64
#  29  SplyFF              4329 non-null   float64
#  30  TxCnt               4329 non-null   float64
#  31  TxTfrCnt            4329 non-null   float64
#  32  TxTfrValAdjNtv      4329 non-null   float64
#  33  TxTfrValAdjUSD      3768 non-null   float64
#  34  TxTfrValMeanNtv     4071 non-null   float64
#  35  TxTfrValMeanUSD     3768 non-null   float64
#  36  TxTfrValMedNtv      4071 non-null   float64
#  37  TxTfrValMedUSD      3768 non-null   float64
#  38  TxTfrValNtv         4329 non-null   float64
#  39  TxTfrValUSD         3768 non-null   float64
#  40  VtyDayRet180d       3588 non-null   float64
#  41  VtyDayRet30d        3738 non-null   float64
#  42  VtyDayRet60d        3708 non-null   float64
# dtypes: float64(42), object(1)
# memory usage: 1.4+ MB

# %%
#The variable definitions for each column is in the 'metrics_info.csv' file.
metrics_info = pd.read_csv('../data/raw/metrics_info.csv').transpose()
#Here I also name the columns with the id row and "erase" the 'id' row.
metrics_info.columns = metrics_info.loc['id']
metrics_info = metrics_info.loc['name': 'description']
metrics_info
# Out:
# id                                                   AdrActCnt  \
# name                                  Addresses, active, count
# category                                             Addresses
# subcategory                                             Active
# type                                                       Sum
# unit                                                 Addresses
# interval                                                 1 day
# interval_rt                                            1 block
# description  The sum count of unique addresses that were ac...
#
# id                                                      BlkCnt  \
# name                                              Block, count
# category                                         Network Usage
# subcategory                                             Blocks
# type                                                       Sum
# unit                                                    Blocks
# interval                                                 1 day
# interval_rt                                                NaN
# description  The sum count of blocks created that interval ...
#
# id                                                 BlkSizeByte  \
# name                                        Block, size, bytes
# category                                         Network Usage
# subcategory                                             Blocks
# type                                                       Sum
# unit                                                     Bytes
# interval                                                 1 day
# interval_rt                                            1 block
# description  The sum of the size (in bytes) of all blocks c...
#
# id                                             BlkSizeMeanByte  \
# name                                  Block, size, mean, bytes
# category                                         Network Usage
# subcategory                                             Blocks
# type                                                      Mean
# unit                                                     Bytes
# interval                                                 1 day
# interval_rt                                                NaN
# description  The mean size (in bytes) of all blocks created...
#
# id                                                  CapMVRVCur  \
# name                      Capitalization, MVRV, current supply
# category                                                Market
# subcategory                              Market Capitalization
# type                                                     Ratio
# unit                                             Dimensionless
# interval                                                 1 day
# interval_rt                                                NaN
# description  The ratio of the sum USD value of the current ...
#
# id                                               CapMrktCurUSD  \
# name               Capitalization, market, current supply, USD
# category                                                Market
# subcategory                              Market Capitalization
# type                                                   Product
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                                NaN
# description  The sum USD value of the current supply. Also ...
#
# id                                                  CapRealUSD  \
# name                             Capitalization, realized, USD
# category                                                Market
# subcategory                              Market Capitalization
# type                                                   Product
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                                NaN
# description  The sum USD value based on the USD closing pri...
#
# id                                                    DiffMean  \
# name                                          Difficulty, mean
# category                                                Mining
# subcategory                                         Difficulty
# type                                                      Mean
# unit                                             Dimensionless
# interval                                                 1 day
# interval_rt                                            1 block
# description  The mean difficulty of finding a hash that mee...
#
# id                                                  FeeMeanNtv  \
# name                     Fees, transaction, mean, native units
# category                                      Fees and Revenue
# subcategory                                               Fees
# type                                                      Mean
# unit                                              Native units
# interval                                                 1 day
# interval_rt                                            1 block
# description  The mean fee per transaction in native units t...
#
# id                                                  FeeMeanUSD  ...  \
# name                              Fees, transaction, mean, USD  ...
# category                                      Fees and Revenue  ...
# subcategory                                               Fees  ...
# type                                                      Mean  ...
# unit                                                       USD  ...
# interval                                                 1 day  ...
# interval_rt                                            1 block  ...
# description  The USD value of the mean fee per transaction ...  ...
#
# id                                              TxTfrValAdjUSD  \
# name             Transactions, transfers, value, adjusted, USD
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                       Sum
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                                NaN
# description  The USD value of the sum of native units trans...
#
# id                                             TxTfrValMeanNtv  \
# name         Transactions, transfers, value, mean, native u...
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                      Mean
# unit                                              Native units
# interval                                                 1 day
# interval_rt                                            1 block
# description  The mean count of native units transferred per...
#
# id                                             TxTfrValMeanUSD  \
# name                 Transactions, transfers, value, mean, USD
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                      Mean
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                            1 block
# description  The sum USD value of native units transferred ...
#
# id                                              TxTfrValMedNtv  \
# name         Transactions, transfers, value, median, native...
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                    Median
# unit                                              Native units
# interval                                                 1 day
# interval_rt                                            1 block
# description  The median count of native units transferred p...
#
# id                                              TxTfrValMedUSD  \
# name               Transactions, transfers, value, median, USD
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                    Median
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                            1 block
# description  The median USD value transferred per transfer ...
#
# id                                                 TxTfrValNtv  \
# name              Transactions, transfers, value, native units
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                       Sum
# unit                                              Native units
# interval                                                 1 day
# interval_rt                                            1 block
# description  The sum of native units transferred (i.e., the...
#
# id                                                 TxTfrValUSD  \
# name                       Transactions, transfers, value, USD
# category                                          Transactions
# subcategory                                     Transfer Value
# type                                                       Sum
# unit                                                       USD
# interval                                                 1 day
# interval_rt                                            1 block
# description  The sum USD value of all native units transfer...
#
# id                                               VtyDayRet180d  \
# name                           Volatility, daily returns, 180d
# category                                                Market
# subcategory                                         Volatility
# type                                                     Ratio
# unit                                             Dimensionless
# interval                                              180 days
# interval_rt                                                NaN
# description  The 180D volatility, measured as the standard ...
#
# id                                                VtyDayRet30d  \
# name                            Volatility, daily returns, 30d
# category                                                Market
# subcategory                                         Volatility
# type                                                     Ratio
# unit                                             Dimensionless
# interval                                               30 days
# interval_rt                                                NaN
# description  The 30D volatility, measured as the standard d...
#
# id                                                VtyDayRet60d
# name                            Volatility, daily returns, 60d
# category                                                Market
# subcategory                                         Volatility
# type                                                     Ratio
# unit                                             Dimensionless
# interval                                               60 days
# interval_rt                                                NaN
# description  The 60D volatility, measured as the standard d...
#
# [8 rows x 42 columns]

# %%
#null values of PriceUSD column
Counter(pd.isnull(raw_data['PriceUSD']))
# Out:
# Counter({True: 561, False: 3768})

# %%
#Sumamry statistics
raw_data.describe()
# Out:
#           AdrActCnt       BlkCnt   BlkSizeByte  BlkSizeMeanByte   CapMVRVCur  \
# count  4.329000e+03  4329.000000  4.329000e+03     4.323000e+03  3768.000000
# mean   3.382061e+05   151.588127  7.146703e+07     4.791262e+05     2.031752
# std    3.310669e+05    35.407708  6.587028e+07     4.463087e+05     3.023974
# min    0.000000e+00     0.000000  0.000000e+00     2.150000e+02     0.386829
# 25%    1.655600e+04   138.000000  3.239007e+06     2.181104e+04     1.239964
# 50%    2.225320e+05   152.000000  4.886839e+07     3.306393e+05     1.667046
# 75%    6.375320e+05   166.000000  1.345631e+08     9.238366e+05     2.211692
# max    1.290363e+06   692.000000  2.565337e+08     1.427240e+06   146.038332
#
#        CapMrktCurUSD    CapRealUSD      DiffMean   FeeMeanNtv   FeeMeanUSD  \
# count   3.768000e+03  4.329000e+03  4.323000e+03  4071.000000  3768.000000
# mean    4.844994e+10  2.592698e+10  2.457234e+12     0.000925     1.113197
# std     6.997915e+10  3.992958e+10  4.839604e+12     0.007783     3.732914
# min     1.776705e+05  0.000000e+00  1.000000e+00     0.000000     0.000000
# 25%     2.852561e+08  4.297248e+07  1.508590e+06     0.000138     0.031508
# 50%     6.783749e+09  4.162094e+09  4.000747e+10     0.000232     0.109961
# 75%     9.664128e+10  4.454662e+10  1.452840e+12     0.000684     0.736531
# max     3.288988e+11  1.269308e+11  1.999734e+13     0.220000    56.308124
#
#        ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  TxTfrValMedNtv  \
# count  ...    3.768000e+03      4071.000000      3768.000000    4.071000e+03
# mean   ...    7.940446e+08        96.037718      3986.735857    5.534117e+01
# std    ...    1.237193e+09       681.259821      5440.151851    6.438631e+02
# min    ...    4.647065e+02         0.010000         0.762873    1.000000e-08
# 25%    ...    1.182070e+07         1.533540       520.062161    1.186364e-02
# 50%    ...    1.453223e+08         3.533065      1691.431740    2.876121e-02
# 75%    ...    1.382788e+09        21.897040      6179.478313    1.000000e-01
# max    ...    1.082210e+10     22175.000000     51124.770624    2.217500e+04
#
#        TxTfrValMedUSD   TxTfrValNtv   TxTfrValUSD  VtyDayRet180d  \
# count    3.768000e+03  4.329000e+03  3.768000e+03    3588.000000
# mean     3.733364e+01  1.052591e+06  2.477263e+09       0.048956
# std      5.175047e+01  1.925106e+06  4.356325e+09       0.021260
# min      8.203471e-08  0.000000e+00  5.874592e+02       0.020298
# 25%      3.373020e+00  3.575082e+05  4.780190e+07       0.032673
# 50%      1.472977e+01  6.790495e+05  5.446225e+08       0.042605
# 75%      6.566664e+01  1.284877e+06  3.823971e+09       0.059114
# max      5.348536e+02  6.725965e+07  4.877049e+10       0.109532
#
#        VtyDayRet30d  VtyDayRet60d
# count   3738.000000   3708.000000
# mean       0.043950      0.045993
# std        0.029770      0.026851
# min        0.007481      0.010406
# 25%        0.024656      0.027685
# 50%        0.035437      0.038460
# 75%        0.053284      0.057796
# max        0.191722      0.143269
#
# [8 rows x 42 columns]

# %%
#setting date column as index and droping it from columns
raw_data.index = raw_data['time']
raw_data = raw_data.drop('time', axis='columns')
raw_data.tail()
# Out:
#             AdrActCnt  BlkCnt  BlkSizeByte  BlkSizeMeanByte  CapMVRVCur  \
# time
# 2020-11-05  1071518.0   147.0  188078794.0     1.279448e+06    2.307493
# 2020-11-06  1080743.0   153.0  194685185.0     1.272452e+06    2.299192
# 2020-11-07  1055012.0   146.0  198604086.0     1.360302e+06    2.187115
# 2020-11-08   920529.0   138.0  189145770.0     1.370622e+06    2.269764
# 2020-11-09  1188873.0   185.0  252934375.0     1.367213e+06    2.237517
#
#             CapMrktCurUSD    CapRealUSD      DiffMean  FeeMeanNtv  FeeMeanUSD  \
# time
# 2020-11-05   2.892633e+11  1.253583e+11  1.678778e+13    0.000831   12.973713
# 2020-11-06   2.895100e+11  1.259182e+11  1.678778e+13    0.000684   10.684208
# 2020-11-07   2.755732e+11  1.259985e+11  1.678778e+13    0.000500    7.437259
# 2020-11-08   2.873323e+11  1.265912e+11  1.678778e+13    0.000384    5.955396
# 2020-11-09   2.840099e+11  1.269308e+11  1.678778e+13    0.000440    6.745236
#
#             ...  TxTfrValAdjUSD  TxTfrValMeanNtv  TxTfrValMeanUSD  \
# time        ...
# 2020-11-05  ...    6.896637e+09         0.947055     14780.185040
# 2020-11-06  ...    5.377085e+09         0.798253     12467.889939
# 2020-11-07  ...    3.113639e+09         0.600304      8924.329906
# 2020-11-08  ...    2.807229e+09         0.637306      9878.241843
# 2020-11-09  ...    4.587933e+09         0.713117     10924.823338
#
#             TxTfrValMedNtv  TxTfrValMedUSD    TxTfrValNtv   TxTfrValUSD  \
# time
# 2020-11-05        0.010560      164.807879  835637.914064  1.304136e+10
# 2020-11-06        0.008849      138.219785  706950.322346  1.104184e+10
# 2020-11-07        0.006843      101.735828  444455.314929  6.607431e+09
# 2020-11-08        0.006680      103.540005  420998.539315  6.525478e+09
# 2020-11-09        0.008200      125.622524  603186.409034  9.240707e+09
#
#             VtyDayRet180d  VtyDayRet30d  VtyDayRet60d
# time
# 2020-11-05       0.026765      0.024748      0.022112
# 2020-11-06       0.025758      0.024822      0.022120
# 2020-11-07       0.026023      0.027211      0.022916
# 2020-11-08       0.026128      0.027797      0.023359
# 2020-11-09       0.025851      0.028047      0.023476
#
# [5 rows x 42 columns]

# %%
raw_data['PriceUSD'].tail()
# Out:
# time
# 2020-11-05    15606.466834
# 2020-11-06    15618.972471
# 2020-11-07    14866.356305
# 2020-11-08    15500.000707
# 2020-11-09    15319.819973
# Name: PriceUSD, dtype: float64
